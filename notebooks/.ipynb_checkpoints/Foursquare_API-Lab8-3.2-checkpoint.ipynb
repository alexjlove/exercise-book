# %% [markdown]
# # Setting up Foursquare data for analysis

# %% [markdown]
# Setup your access token to foursquare

# %%
import foursquare
import json
import pandas as pd
import unicodedata

#ACCESS_TOKEN = ""
#client = foursquare.Foursquare(access_token=ACCESS_TOKEN)

CLIENT_ID = 'YU0GZL10NTN4C4OJ5RIFEVSZXZHSHJNT5D0BIE4MQ5MVKRPL'
CLIENT_SECRET = 'JVHGANJF203WEN3X0MOJJ2DQRKJFNX1TL2H0SRYWMNQIHKOJ'
client = foursquare.Foursquare(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)

# %% [markdown]
# Use a foursquare python library method to search for suitable venues around a city near you. Print the associated JSON output in a nice way with appropriate spacing and indentation

# %%
starting_list = client.venues.search(params={'near': 'Seattle, WA', 'radius': 1500})

# %% [markdown]
# Wow... that should look like a total mess to you. Read the following docs: https://docs.python.org/2/library/json.html, and read the part about pretty printing. Once you think you've understood the method, deploy it here and see the world a difference a bit of spacing and indenting makes!

# %%
print (json.dumps(starting_list, indent = 4))
# Out:
# {
#     "confident": false,
#     "geocode": {
#         "parents": [],
#         "what": "",
#         "where": "seattle wa",
#         "feature": {
#             "highlightedName": "<b>Seattle</b>, <b>WA</b>, United States",
#             "displayName": "Seattle, WA, United States",
#             "name": "Seattle",
#             "longId": "72057594043737780",
#             "cc": "US",
#             "id": "geonameid:5809844",
#             "geometry": {
#                 "center": {
#                     "lat": 47.60621,
#                     "lng": -122.33207
#                 },
#                 "bounds": {
#                     "sw": {
#                         "lat": 47.481719999999996,
#                         "lng": -122.459696
#                     },
#                     "ne": {
#                         "lat": 47.734145,
#                         "lng": -122.224433
#                     }
#                 }
#             },
#             "matchedName": "Seattle, WA, United States",
#             "woeType": 7,
#             "slug": "seattle-washington"
#         }
#     },
#     "venues": [
#         {
#             "verified": false,
#             "name": "PitchBook",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {
#                 "twitter": "PitchBook"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60588738301708,
#                         "lng": -122.33191088158196,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98164",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "901 5th Ave Suite 1200",
#                     "Seattle, WA 98164",
#                     "United States"
#                 ],
#                 "address": "901 5th Ave Suite 1200",
#                 "lat": 47.60588738301708,
#                 "lng": -122.33191088158196
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1356,
#                 "usersCount": 51
#             },
#             "id": "4d5435bab3d9a35d2513cb7b",
#             "categories": [
#                 {
#                     "pluralName": "Offices",
#                     "primary": true,
#                     "name": "Office",
#                     "shortName": "Office",
#                     "id": "4bf58dd8d48988d124941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Downtown Seattle",
#             "referralId": "v-1477452743",
#             "url": "http://www.downtownseattle.com",
#             "hereNow": {
#                 "count": 4,
#                 "groups": [
#                     {
#                         "count": 4,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "4 people are here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [],
#             "contact": {
#                 "facebookName": "Downtown Seattle",
#                 "twitter": "downtownseattle",
#                 "phone": "2068160558",
#                 "facebook": "78512577198",
#                 "formattedPhone": "(206) 816-0558",
#                 "facebookUsername": "DowntownSeattle"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98101",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "Seattle, WA 98101",
#                     "United States"
#                 ],
#                 "lat": 47.609772656756974,
#                 "lng": -122.33626097897249
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 38,
#                 "checkinsCount": 62139,
#                 "usersCount": 13903
#             },
#             "id": "4c73334913228cfa364e2d65",
#             "categories": [
#                 {
#                     "pluralName": "Neighborhoods",
#                     "primary": true,
#                     "name": "Neighborhood",
#                     "shortName": "Neighborhood",
#                     "id": "4f2a25ac4b909258e854f55f",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Seattle Public Library (Seattle Central Library)",
#             "referralId": "v-1477452743",
#             "url": "http://www.spl.org/locations/central-library",
#             "hereNow": {
#                 "count": 3,
#                 "groups": [
#                     {
#                         "count": 3,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "3 people are here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [],
#             "contact": {
#                 "facebookName": "The Seattle Public Library",
#                 "twitter": "SPLBuzz",
#                 "phone": "2063864636",
#                 "facebook": "7511741338",
#                 "formattedPhone": "(206) 386-4636",
#                 "facebookUsername": "SeattlePublicLibrary"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98104",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "1000 4th Ave (btwn Madison and Spring)",
#                     "Seattle, WA 98104",
#                     "United States"
#                 ],
#                 "crossStreet": "btwn Madison and Spring",
#                 "address": "1000 4th Ave",
#                 "lat": 47.606716413446364,
#                 "lng": -122.33262419700623
#             },
#             "venuePage": {
#                 "id": "78244976"
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 141,
#                 "checkinsCount": 24771,
#                 "usersCount": 11053
#             },
#             "id": "42a78680f964a52011251fe3",
#             "categories": [
#                 {
#                     "pluralName": "Libraries",
#                     "primary": true,
#                     "name": "Library",
#                     "shortName": "Library",
#                     "id": "4bf58dd8d48988d12f941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/library_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Kurt Cobain Park",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60629412238088,
#                         "lng": -122.3320513504519,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "seattle",
#                     "Seattle, WA",
#                     "United States"
#                 ],
#                 "address": "seattle",
#                 "lat": 47.60629412238088,
#                 "lng": -122.3320513504519
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 115,
#                 "usersCount": 81
#             },
#             "id": "4c3a70261a38ef3b69229321",
#             "categories": [
#                 {
#                     "pluralName": "Parks",
#                     "primary": true,
#                     "name": "Park",
#                     "shortName": "Park",
#                     "id": "4bf58dd8d48988d163941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "City of Seattle",
#             "referralId": "v-1477452743",
#             "url": "http://www.seattle.gov",
#             "hereNow": {
#                 "count": 1,
#                 "groups": [
#                     {
#                         "count": 1,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "One other person is here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [],
#             "contact": {
#                 "facebookName": "Seattle City Council",
#                 "twitter": "cityofseattle",
#                 "phone": "2066842489",
#                 "facebook": "113291465167",
#                 "formattedPhone": "(206) 684-2489",
#                 "facebookUsername": "seattlecouncil"
#             },
#             "hasPerk": false,
#             "location": {
#                 "cc": "US",
#                 "country": "United States",
#                 "state": "Washington",
#                 "formattedAddress": [
#                     "Washington",
#                     "United States"
#                 ],
#                 "lat": 47.608752618414165,
#                 "lng": -122.34008073806763
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 53,
#                 "checkinsCount": 60365,
#                 "usersCount": 16292
#             },
#             "id": "4c4e36c7d667d13aef800aa0",
#             "categories": [
#                 {
#                     "pluralName": "Cities",
#                     "primary": true,
#                     "name": "City",
#                     "shortName": "City",
#                     "id": "50aa9e094b90af0d42d5de0d",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "5th and Madison Condos",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60624,
#                         "lng": -122.332125,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98164",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "909 5th Ave (Madison)",
#                     "Seattle, WA 98164",
#                     "United States"
#                 ],
#                 "crossStreet": "Madison",
#                 "address": "909 5th Ave",
#                 "lat": 47.60624,
#                 "lng": -122.332125
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 16,
#                 "usersCount": 11
#             },
#             "id": "54034b84498e97b4651704e9",
#             "categories": [
#                 {
#                     "pluralName": "Residential Buildings (Apartments / Condos)",
#                     "primary": true,
#                     "name": "Residential Building (Apartment / Condo)",
#                     "shortName": "Residential",
#                     "id": "4d954b06a243a5684965b473",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/apartment_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "901 Fifth Avenue Building",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.605968644099654,
#                         "lng": -122.3318288744366,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98164",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "901 5th Ave (at Madison St)",
#                     "Seattle, WA 98164",
#                     "United States"
#                 ],
#                 "crossStreet": "at Madison St",
#                 "address": "901 5th Ave",
#                 "lat": 47.605968644099654,
#                 "lng": -122.3318288744366
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1739,
#                 "usersCount": 198
#             },
#             "id": "4ba67df6f964a520c25739e3",
#             "categories": [
#                 {
#                     "pluralName": "Buildings",
#                     "primary": true,
#                     "name": "Building",
#                     "shortName": "Building",
#                     "id": "4bf58dd8d48988d130941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Luly Yang Couture",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "url": "http://www.lulyyang.com",
#             "storeId": "",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "2066238200",
#                 "twitter": "lulyyangcouture",
#                 "formattedPhone": "(206) 623-8200"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60825463856766,
#                         "lng": -122.33481775350242,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98101",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "1218 4th Ave",
#                     "Seattle, WA 98101",
#                     "United States"
#                 ],
#                 "address": "1218 4th Ave",
#                 "lat": 47.60825463856766,
#                 "lng": -122.33481775350242
#             },
#             "venuePage": {
#                 "id": "42963646"
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 2,
#                 "checkinsCount": 299,
#                 "usersCount": 126
#             },
#             "id": "4b0dc329f964a520954f23e3",
#             "categories": [
#                 {
#                     "pluralName": "Bridal Shops",
#                     "primary": true,
#                     "name": "Bridal Shop",
#                     "shortName": "Bridal",
#                     "id": "4bf58dd8d48988d11a951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/bridal_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Seattle Department Of Transportation",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60537973715986,
#                         "lng": -122.33041622969527,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "Seattle, WA",
#                     "United States"
#                 ],
#                 "lat": 47.60537973715986,
#                 "lng": -122.33041622969527
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 26,
#                 "usersCount": 24
#             },
#             "id": "4e14d23ab61c42e7c545a5dc",
#             "categories": [
#                 {
#                     "pluralName": "Government Buildings",
#                     "primary": true,
#                     "name": "Government Building",
#                     "shortName": "Government",
#                     "id": "4bf58dd8d48988d126941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/government_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "hasMenu": true,
#             "verified": false,
#             "name": "Cafe 5ive",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "menu": {
#                 "url": "https://foursquare.com/v/cafe-5ive/4bda077f3904a59325bf449e/menu",
#                 "mobileUrl": "https://foursquare.com/v/4bda077f3904a59325bf449e/device_menu",
#                 "type": "Menu",
#                 "anchor": "View Menu",
#                 "label": "Menu"
#             },
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "2066211242",
#                 "twitter": "cafe5ive",
#                 "formattedPhone": "(206) 621-1242"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60599717066324,
#                         "lng": -122.33176064828876,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98164",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "901 5th Ave Ste 820",
#                     "Seattle, WA 98164",
#                     "United States"
#                 ],
#                 "address": "901 5th Ave Ste 820",
#                 "lat": 47.60599717066324,
#                 "lng": -122.33176064828876
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 3,
#                 "checkinsCount": 465,
#                 "usersCount": 84
#             },
#             "id": "4bda077f3904a59325bf449e",
#             "categories": [
#                 {
#                     "pluralName": "Caf\u00e9s",
#                     "primary": true,
#                     "name": "Caf\u00e9",
#                     "shortName": "Caf\u00e9",
#                     "id": "4bf58dd8d48988d16d941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Metro Bus Stop #660",
#             "referralId": "v-1477452743",
#             "url": "http://kingcounty.gov/metro",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [],
#             "contact": {
#                 "phone": "2065533000",
#                 "twitter": "kcmetrobus",
#                 "formattedPhone": "(206) 553-3000"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60606900662651,
#                         "lng": -122.33278512954712,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98104",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "4th Ave (at Madison St)",
#                     "Seattle, WA 98104",
#                     "United States"
#                 ],
#                 "crossStreet": "at Madison St",
#                 "address": "4th Ave",
#                 "lat": 47.60606900662651,
#                 "lng": -122.33278512954712
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 2,
#                 "checkinsCount": 374,
#                 "usersCount": 72
#             },
#             "id": "4c69c67896f176b0202aa836",
#             "categories": [
#                 {
#                     "pluralName": "Bus Stops",
#                     "primary": true,
#                     "name": "Bus Stop",
#                     "shortName": "Bus Stop",
#                     "id": "52f2ab2ebcbc57f1066b8b4f",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/busstation_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Ernst & Young",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {
#                 "phone": "2066211800",
#                 "formattedPhone": "(206) 621-1800"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60551040887555,
#                         "lng": -122.33406682325993,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98104",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "999 3rd Ave",
#                     "Seattle, WA 98104",
#                     "United States"
#                 ],
#                 "address": "999 3rd Ave",
#                 "lat": 47.60551040887555,
#                 "lng": -122.33406682325993
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 682,
#                 "usersCount": 58
#             },
#             "id": "4b86cd31f964a5204b9e31e3",
#             "categories": [
#                 {
#                     "pluralName": "Coworking Spaces",
#                     "primary": true,
#                     "name": "Coworking Space",
#                     "shortName": "Coworking Space",
#                     "id": "4bf58dd8d48988d174941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Vovito Espresso Gelato Bar",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "url": "http://vovito.com",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "facebookName": "Vovito Caff\u00e8 & Gelato",
#                 "twitter": "vovitocaffe",
#                 "phone": "4255035522",
#                 "facebook": "140904155928637",
#                 "formattedPhone": "(425) 503-5522",
#                 "facebookUsername": "vovitocaffe"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.606893,
#                         "lng": -122.33359,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98101",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "1100 4th Ave",
#                     "Seattle, WA 98101",
#                     "United States"
#                 ],
#                 "address": "1100 4th Ave",
#                 "lat": 47.606893,
#                 "lng": -122.33359
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 11,
#                 "checkinsCount": 531,
#                 "usersCount": 374
#             },
#             "id": "5216296a11d273fe5b77c721",
#             "categories": [
#                 {
#                     "pluralName": "Caf\u00e9s",
#                     "primary": true,
#                     "name": "Caf\u00e9",
#                     "shortName": "Caf\u00e9",
#                     "id": "4bf58dd8d48988d16d941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "The Grilled Cheese Experience",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "url": "http://grilledcheeseseattle.com",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "2066615225",
#                 "formattedPhone": "(206) 661-5225"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60636125783046,
#                         "lng": -122.33349882265152,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98109",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "Rainier (Mead)",
#                     "Seattle, WA 98109",
#                     "United States"
#                 ],
#                 "crossStreet": "Mead",
#                 "address": "Rainier",
#                 "lat": 47.60636125783046,
#                 "lng": -122.33349882265152
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 7,
#                 "checkinsCount": 446,
#                 "usersCount": 301
#             },
#             "id": "50202aaae4b091a446dcee3b",
#             "categories": [
#                 {
#                     "pluralName": "Food Trucks",
#                     "primary": true,
#                     "name": "Food Truck",
#                     "shortName": "Food Truck",
#                     "id": "4bf58dd8d48988d1cb941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/streetfood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Martial Sports",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.606209,
#                         "lng": -122.332071,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98164",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "Seattle, WA 98164",
#                     "United States"
#                 ],
#                 "lat": 47.606209,
#                 "lng": -122.332071
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1,
#                 "usersCount": 1
#             },
#             "id": "4f0cd8a7e4b08ead5d4f37eb",
#             "categories": [
#                 {
#                     "pluralName": "Martial Arts Dojos",
#                     "primary": true,
#                     "name": "Martial Arts Dojo",
#                     "shortName": "Martial Arts",
#                     "id": "4bf58dd8d48988d101941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Off The Coast Of Eden",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.606209,
#                         "lng": -122.332071,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98164",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "Sea",
#                     "Seattle, WA 98164",
#                     "United States"
#                 ],
#                 "address": "Sea",
#                 "lat": 47.606209,
#                 "lng": -122.332071
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1,
#                 "usersCount": 1
#             },
#             "id": "4ef001f793ad3fada0aa8a43",
#             "categories": [
#                 {
#                     "pluralName": "Boats or Ferries",
#                     "primary": true,
#                     "name": "Boat or Ferry",
#                     "shortName": "Boat / Ferry",
#                     "id": "4bf58dd8d48988d12d951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/boat_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "History News Network",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.606206922022494,
#                         "lng": -122.33207005141776,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98104",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "119 S Main St",
#                     "Seattle, WA 98104",
#                     "United States"
#                 ],
#                 "address": "119 S Main St",
#                 "lat": 47.606206922022494,
#                 "lng": -122.33207005141776
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 4,
#                 "usersCount": 4
#             },
#             "id": "4cbf7e0a19ceb1f786c423cd",
#             "categories": [
#                 {
#                     "pluralName": "College Libraries",
#                     "primary": true,
#                     "name": "College Library",
#                     "shortName": "Library",
#                     "id": "4bf58dd8d48988d1a7941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/library_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Silversea Cruise",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.606209,
#                         "lng": -122.332071,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98164",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "sea",
#                     "Seattle, WA 98164",
#                     "United States"
#                 ],
#                 "address": "sea",
#                 "lat": 47.606209,
#                 "lng": -122.332071
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1,
#                 "usersCount": 1
#             },
#             "id": "4f05b2a0e3002adb767db851",
#             "categories": [
#                 {
#                     "pluralName": "Boats or Ferries",
#                     "primary": true,
#                     "name": "Boat or Ferry",
#                     "shortName": "Boat / Ferry",
#                     "id": "4bf58dd8d48988d12d951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/boat_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Runway Shoes",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "2066823355",
#                 "formattedPhone": "(206) 682-3355"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.606206922022494,
#                         "lng": -122.33207005141776,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98101",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "400 Pine St",
#                     "Seattle, WA 98101",
#                     "United States"
#                 ],
#                 "address": "400 Pine St",
#                 "lat": 47.606206922022494,
#                 "lng": -122.33207005141776
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 11,
#                 "usersCount": 11
#             },
#             "id": "4cc37e8bbde8f04d36b4a54b",
#             "categories": [
#                 {
#                     "pluralName": "Shoe Stores",
#                     "primary": true,
#                     "name": "Shoe Store",
#                     "shortName": "Shoes",
#                     "id": "4bf58dd8d48988d107951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "T-Mobile (AT&T) Lounge",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.606206922022494,
#                         "lng": -122.33207005141776,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98101",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "1527 4th Ave",
#                     "Seattle, WA 98101",
#                     "United States"
#                 ],
#                 "address": "1527 4th Ave",
#                 "lat": 47.606206922022494,
#                 "lng": -122.33207005141776
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 13,
#                 "usersCount": 13
#             },
#             "id": "4d86a3875e70224b492a3b09",
#             "categories": [
#                 {
#                     "pluralName": "Electronics Stores",
#                     "primary": true,
#                     "name": "Electronics Store",
#                     "shortName": "Electronics",
#                     "id": "4bf58dd8d48988d122951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/technology_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Knobbe Martens",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {
#                 "phone": "2064052000",
#                 "twitter": "ipseattle",
#                 "formattedPhone": "(206) 405-2000"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.606206922022494,
#                         "lng": -122.33207005141776,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98104",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "925 Fourth Ave. (Madison)",
#                     "Seattle, CA 98104",
#                     "United States"
#                 ],
#                 "crossStreet": "Madison",
#                 "address": "925 Fourth Ave.",
#                 "lat": 47.606206922022494,
#                 "lng": -122.33207005141776
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 3,
#                 "usersCount": 3
#             },
#             "id": "54c0083a498eaf5142b1b93b",
#             "categories": [
#                 {
#                     "pluralName": "Offices",
#                     "primary": true,
#                     "name": "Office",
# ...
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 8,
#                 "usersCount": 7
#             },
#             "id": "4c15af4d127f95215f122525",
#             "categories": [
#                 {
#                     "pluralName": "Food Trucks",
#                     "primary": true,
#                     "name": "Food Truck",
#                     "shortName": "Food Truck",
#                     "id": "4bf58dd8d48988d1cb941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/streetfood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Men's Barber",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "2067357137",
#                 "formattedPhone": "(206) 735-7137"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60630104559121,
#                         "lng": -122.3321618967053,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98104",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "410 Spring St (4th Ave)",
#                     "Seattle, WA 98104",
#                     "United States"
#                 ],
#                 "crossStreet": "4th Ave",
#                 "address": "410 Spring St",
#                 "lat": 47.60630104559121,
#                 "lng": -122.3321618967053
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 2,
#                 "usersCount": 2
#             },
#             "id": "5526c11a498edf58951ea549",
#             "categories": [
#                 {
#                     "pluralName": "Health & Beauty Services",
#                     "primary": true,
#                     "name": "Health & Beauty Service",
#                     "shortName": "Health & Beauty",
#                     "id": "54541900498ea6ccd0202697",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Puckett & Redford Attorneys At Law",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60609689999999,
#                         "lng": -122.331981,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "Seattle, WA",
#                     "United States"
#                 ],
#                 "lat": 47.60609689999999,
#                 "lng": -122.331981
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 5,
#                 "usersCount": 3
#             },
#             "id": "4e0e4060e4cd27fc7d2de9a6",
#             "categories": [
#                 {
#                     "pluralName": "Lawyers",
#                     "primary": true,
#                     "name": "Lawyer",
#                     "shortName": "Lawyer",
#                     "id": "52f2ab2ebcbc57f1066b8b3f",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/education/lawschool_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Safeco Plaza",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.606100885453245,
#                         "lng": -122.33371726386186,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98154",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "1001 4th Ave (at Madison Ave)",
#                     "Seattle, WA 98154",
#                     "United States"
#                 ],
#                 "crossStreet": "at Madison Ave",
#                 "address": "1001 4th Ave",
#                 "lat": 47.606100885453245,
#                 "lng": -122.33371726386186
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 4,
#                 "checkinsCount": 4344,
#                 "usersCount": 534
#             },
#             "id": "4ac279b9f964a5204c9920e3",
#             "categories": [
#                 {
#                     "pluralName": "Buildings",
#                     "primary": true,
#                     "name": "Building",
#                     "shortName": "Building",
#                     "id": "4bf58dd8d48988d130941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "ESPN Seattle",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60580606815716,
#                         "lng": -122.33344416359728,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98154",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "Seattle, WA 98154",
#                     "United States"
#                 ],
#                 "lat": 47.60580606815716,
#                 "lng": -122.33344416359728
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 1031,
#                 "usersCount": 112
#             },
#             "id": "4c9252b6ae45224b2549ef97",
#             "categories": [
#                 {
#                     "pluralName": "TV Stations",
#                     "primary": true,
#                     "name": "TV Station",
#                     "shortName": "TV Station",
#                     "id": "52e81612bcbc57f1066b7a31",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "YMCA",
#             "referralId": "v-1477452743",
#             "venueChains": [
#                 {
#                     "id": "5568f419a7c8a9cf8ec4837e"
#                 }
#             ],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "twitter": "SeattleYMCA"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60539334847316,
#                         "lng": -122.33255140495973,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98104",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "909 4th Ave (btw Madison St and Marion St)",
#                     "Seattle, WA 98104",
#                     "United States"
#                 ],
#                 "crossStreet": "btw Madison St and Marion St",
#                 "address": "909 4th Ave",
#                 "lat": 47.60539334847316,
#                 "lng": -122.33255140495973
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 18,
#                 "checkinsCount": 3936,
#                 "usersCount": 476
#             },
#             "id": "49d15a45f964a520785b1fe3",
#             "categories": [
#                 {
#                     "pluralName": "Gyms",
#                     "primary": true,
#                     "name": "Gym",
#                     "shortName": "Gym",
#                     "id": "4bf58dd8d48988d176941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Cray Inc.",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {
#                 "phone": "2067012000",
#                 "formattedPhone": "(206) 701-2000"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.60601683898761,
#                         "lng": -122.33207786607964,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98164",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "901 5th Ave Ste 1000 (at Madison St.)",
#                     "Seattle, WA 98164",
#                     "United States"
#                 ],
#                 "crossStreet": "at Madison St.",
#                 "address": "901 5th Ave Ste 1000",
#                 "lat": 47.60601683898761,
#                 "lng": -122.33207786607964
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 47,
#                 "usersCount": 29
#             },
#             "id": "4db5c24e5da3a76f44588795",
#             "categories": [
#                 {
#                     "pluralName": "Offices",
#                     "primary": true,
#                     "name": "Office",
#                     "shortName": "Office",
#                     "id": "4bf58dd8d48988d124941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "B of A 5th Ave Plaza 33rd Floor",
#             "referralId": "v-1477452743",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Seattle",
#                 "labeledLatLngs": [
#                     {
#                         "lat": 47.606368025207274,
#                         "lng": -122.33198386061265,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "98104",
#                 "state": "WA",
#                 "formattedAddress": [
#                     "Seattle, WA 98104",
#                     "United States"
#                 ],
#                 "lat": 47.606368025207274,
#                 "lng": -122.33198386061265
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 15,
#                 "usersCount": 4
#             },
#             "id": "5022af71e4b05abb1ce0fe1f",
#             "categories": [
#                 {
#                     "pluralName": "Buildings",
#                     "primary": true,
#                     "name": "Building",
#                     "shortName": "Building",
#                     "id": "4bf58dd8d48988d130941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         }
#     ]
# }

# %% [markdown]
# Now that we can make some sense of the structure let's practice traversing the JSON hieararchy, select one of the venues in the list and output it's name

# %%
starting_list['venues'][3]['name']
# Out:
# u'Kurt Cobain Park'

# %%
type(temp['venues'][1]['name'])
# Out:
# unicode

# %% [markdown]
# Note that the output isn't exactly what we want. It says u'Park', and if you check the type, Python will output Unicode. This isn't good, we need to recover the original intended type. Read the following docs:
#
# https://docs.python.org/2/library/unicodedata.html, and checkup the method 'normalize'. Once you think you've understood this method. Implement it on the above call and see if you can recover the appropriate type for that data.

# %%
temp['venues'][2]['name'].encode('ascii', 'ignore')
# Out:
# 'Seattle Public Library (Seattle Central Library)'

# %% [markdown]
# Now for some exploratory analysis, let's print the number of total venues in your list

# %%
len(temp['venues'])
# Out:
# 30

# %% [markdown]
# Extract the location id for your starting list. Make sure it's normalized to its correct type, and not Unicode. Put this id in a variable called temp. From this id, we will get a list of other venues.

# %%
temp = starting_list['venues'][2]['id'].encode('ascii', 'ignore')

# %% [markdown]
# Print the venues list (in the nicely formatted JSON)

# %%
temp1 = client.venues(temp)
print(json.dumps(temp1, indent = 4))
# Out:
# {
#     "venue": {
#         "rating": 9.3,
#         "reasons": {
#             "count": 1,
#             "items": [
#                 {
#                     "reasonName": "rawLikesReason",
#                     "type": "general",
#                     "summary": "Lots of people like this place"
#                 }
#             ]
#         },
#         "likes": {
#             "count": 447,
#             "groups": [
#                 {
#                     "count": 447,
#                     "items": [],
#                     "type": "others"
#                 }
#             ],
#             "summary": "447 Likes"
#         },
#         "beenHere": {
#             "count": 0,
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "id": "42a78680f964a52011251fe3",
#         "createdAt": 1118275200,
#         "description": "Our Vision for Seattle: A city where imagination and opportunity thrive. \r\nOur Mission: The Seattle Public Library brings people, information and ideas together to enrich lives and build community.",
#         "verified": true,
#         "venueRatingBlacklisted": true,
#         "hereNow": {
#             "count": 2,
#             "groups": [
#                 {
#                     "count": 2,
#                     "items": [],
#                     "type": "others",
#                     "name": "Other people here"
#                 }
#             ],
#             "summary": "2 people are here"
#         },
#         "shortUrl": "http://4sq.com/2VcZRz",
#         "pageUpdates": {
#             "count": 0,
#             "items": []
#         },
#         "contact": {
#             "facebookName": "The Seattle Public Library",
#             "twitter": "splbuzz",
#             "phone": "2063864636",
#             "facebook": "7511741338",
#             "formattedPhone": "(206) 386-4636",
#             "facebookUsername": "SeattlePublicLibrary"
#         },
#         "location": {
#             "city": "Seattle",
#             "cc": "US",
#             "country": "United States",
#             "postalCode": "98104",
#             "state": "WA",
#             "formattedAddress": [
#                 "1000 4th Ave (btwn Madison and Spring)",
#                 "Seattle, WA 98104",
#                 "United States"
#             ],
#             "crossStreet": "btwn Madison and Spring",
#             "address": "1000 4th Ave",
#             "lat": 47.606716413446364,
#             "lng": -122.33262419700623
#         },
#         "venuePage": {
#             "id": "78244976"
#         },
#         "dislike": false,
#         "bestPhoto": {
#             "suffix": "/16720239_VKZ_4tjfwz8_pLF6HaKffNW9NFZC8tMx6bxec_QAh0w.jpg",
#             "width": 717,
#             "visibility": "public",
#             "height": 959,
#             "source": {
#                 "url": "https://foursquare.com/download/#/iphone",
#                 "name": "Foursquare for iOS"
#             },
#             "prefix": "https://irs0.4sqi.net/img/general/",
#             "id": "51c61841498e7baf21719fe3",
#             "createdAt": 1371936833
#         },
#         "listed": {
#             "count": 437,
#             "groups": [
#                 {
#                     "count": 437,
#                     "items": [
#                         {
#                             "description": "",
#                             "collaborative": false,
#                             "url": "/katekkkkkkk/list/lost-in-seattle",
#                             "photo": {
#                                 "suffix": "/W4QQ0q2CVM_Ynk5O2-bYhUslnqihN7RAvjWIq6KnYss.jpg",
#                                 "visibility": "public",
#                                 "height": 537,
#                                 "width": 720,
#                                 "prefix": "https://irs3.4sqi.net/img/general/",
#                                 "user": {
#                                     "gender": "female",
#                                     "firstName": "Kate",
#                                     "lastName": "K",
#                                     "photo": {
#                                         "prefix": "https://irs0.4sqi.net/img/user/",
#                                         "suffix": "/6717307-ZNL044QKV5KIVW5D.jpg"
#                                     },
#                                     "isAnonymous": false,
#                                     "id": "6717307"
#                                 },
#                                 "id": "4f8b9efde4b0e67b8719e91b",
#                                 "createdAt": 1334550269
#                             },
#                             "editable": false,
#                             "listItems": {
#                                 "count": 187,
#                                 "items": [
#                                     {
#                                         "photo": {
#                                             "suffix": "/BNQ41M1XNV0W5QVEYPJHLSBMP5PA2WCKLU4UABABN2DBNWN1.jpg",
#                                             "visibility": "public",
#                                             "height": 720,
#                                             "width": 540,
#                                             "prefix": "https://irs1.4sqi.net/img/general/",
#                                             "user": {
#                                                 "gender": "male",
#                                                 "firstName": "Roberto",
#                                                 "lastName": "Ju\u00e1rez-Garza",
#                                                 "photo": {
#                                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                                     "suffix": "/4AWGWSB0ZKXEH001.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "75217"
#                                             },
#                                             "id": "4e89361930f8cfdcae495a8e",
#                                             "createdAt": 1317615129
#                                         },
#                                         "id": "t4ccaf04d52af9c74d9d1a864",
#                                         "createdAt": 1327350708
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1321372225,
#                             "public": true,
#                             "followers": {
#                                 "count": 219
#                             },
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Kate",
#                                 "lastName": "K",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/6717307-ZNL044QKV5KIVW5D.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "6717307"
#                             },
#                             "updatedAt": 1461990236,
#                             "type": "others",
#                             "id": "4ec28a410e019a162bfa0071",
#                             "canonicalUrl": "https://foursquare.com/katekkkkkkk/list/lost-in-seattle",
#                             "name": "Lost in Seattle"
#                         },
#                         {
#                             "description": "",
#                             "collaborative": false,
#                             "url": "/user/1436904/list/musthave-experiences-in-seattle",
#                             "photo": {
#                                 "suffix": "/S50W3YIUEDX5L3WRCBNYO5DZDMWIQLBCJ3VQLHJIO5AW2SA2.jpg",
#                                 "visibility": "public",
#                                 "height": 612,
#                                 "width": 612,
#                                 "prefix": "https://irs2.4sqi.net/img/general/",
#                                 "user": {
#                                     "gender": "male",
#                                     "firstName": "Eric",
#                                     "lastName": "Tigre",
#                                     "photo": {
#                                         "prefix": "https://irs0.4sqi.net/img/user/",
#                                         "suffix": "/-3JAEIXXJT30PBIB0.png"
#                                     },
#                                     "isAnonymous": false,
#                                     "id": "735213"
#                                 },
#                                 "id": "4dbf4a8040a3e7cd405ce12d",
#                                 "createdAt": 1304382080
#                             },
#                             "editable": false,
#                             "listItems": {
#                                 "count": 105,
#                                 "items": [
#                                     {
#                                         "photo": {
#                                             "suffix": "/ZPITCKWUCOMR5BMZCJ5GXGGU4IG2O133QNPXLYYJFTH0Q2QW.jpg",
#                                             "visibility": "public",
#                                             "height": 720,
#                                             "width": 431,
#                                             "prefix": "https://irs1.4sqi.net/img/general/",
#                                             "user": {
#                                                 "gender": "male",
#                                                 "isAnonymous": false,
#                                                 "id": "205913",
#                                                 "firstName": "Chrisito",
#                                                 "photo": {
#                                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                                     "suffix": "/LU25WC5BWJPRKKMF.jpg"
#                                                 }
#                                             },
#                                             "id": "4e8121dd5c5cc41b9e537708",
#                                             "createdAt": 1317085661
#                                         },
#                                         "id": "t4ccaf04d52af9c74d9d1a864",
#                                         "createdAt": 1317365937
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1317284802,
#                             "public": true,
#                             "followers": {
#                                 "count": 350
#                             },
#                             "user": {
#                                 "gender": "none",
#                                 "isAnonymous": false,
#                                 "id": "1436904",
#                                 "firstName": "\u30c9\u30fc\u30e9\ue013",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/O3GTW2XUG1PGDZOI.jpg"
#                                 }
#                             },
#                             "updatedAt": 1464276279,
#                             "type": "others",
#                             "id": "4e842bc2e5fab91d1ab35b07",
#                             "canonicalUrl": "https://foursquare.com/user/1436904/list/musthave-experiences-in-seattle",
#                             "name": "Must-have Experiences in Seattle"
#                         },
#                         {
#                             "description": "Unlock City badges from @foursquare by visiting venues around USA",
#                             "collaborative": false,
#                             "url": "/2easy4dony/list/4sq-cities-usa",
#                             "editable": false,
#                             "listItems": {
#                                 "count": 75,
#                                 "items": [
#                                     {
#                                         "id": "v42a78680f964a52011251fe3",
#                                         "createdAt": 1331098527
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1330849385,
#                             "public": true,
#                             "followers": {
#                                 "count": 83
#                             },
#                             "user": {
#                                 "gender": "male",
#                                 "isAnonymous": false,
#                                 "id": "1788972",
#                                 "firstName": "Capolista",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/5XQWBOYS1WSZD5YW.jpg"
#                                 }
#                             },
#                             "updatedAt": 1385070081,
#                             "type": "others",
#                             "id": "4f532669e4b0c4160533ea94",
#                             "canonicalUrl": "https://foursquare.com/2easy4dony/list/4sq-cities-usa",
#                             "name": "4sq Cities! (USA)"
#                         },
#                         {
#                             "description": "",
#                             "collaborative": false,
#                             "url": "/romabit/list/seattle-area-oddities",
#                             "photo": {
#                                 "suffix": "/Y4Z4ZLA2ZO4ST2AO031ZNMB0Q2TQILVM2PQBC5DM54425QUW.jpg",
#                                 "visibility": "public",
#                                 "height": 540,
#                                 "width": 720,
#                                 "prefix": "https://irs3.4sqi.net/img/general/",
#                                 "user": {
#                                     "gender": "male",
#                                     "firstName": "Wayne",
#                                     "lastName": "Proctor",
#                                     "photo": {
#                                         "prefix": "https://irs0.4sqi.net/img/user/",
#                                         "suffix": "/YFUODLSSGQNPSI0T.jpg"
#                                     },
#                                     "isAnonymous": false,
#                                     "id": "859328"
#                                 },
#                                 "id": "4e55711818380ed867d81551",
#                                 "createdAt": 1314222360
#                             },
#                             "editable": false,
#                             "listItems": {
#                                 "count": 74,
#                                 "items": [
#                                     {
#                                         "id": "t4ed0212b775bbb5f329415c6",
#                                         "createdAt": 1328426618
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1319302407,
#                             "public": true,
#                             "followers": {
#                                 "count": 98
#                             },
#                             "user": {
#                                 "gender": "female",
#                                 "isAnonymous": false,
#                                 "id": "139454",
#                                 "firstName": "T R",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/YSXOXSFDED3R4QEE.jpg"
#                                 }
#                             },
#                             "updatedAt": 1452166468,
#                             "type": "others",
#                             "id": "4ea2f50793ad755e372e68ef",
#                             "canonicalUrl": "https://foursquare.com/romabit/list/seattle-area-oddities",
#                             "name": "Seattle Area Oddities"
#                         }
#                     ],
#                     "type": "others",
#                     "name": "Lists from other people"
#                 }
#             ]
#         },
#         "canonicalUrl": "https://foursquare.com/v/seattle-public-library/42a78680f964a52011251fe3",
#         "tags": [
#             "aia national",
#             "architecture",
#             "books",
#             "cafe",
#             "cd",
#             "dvd",
#             "library",
#             "literature",
#             "movies",
#             "music",
#             "public computers",
#             "quiet",
#             "reading",
#             "rem koolhaas",
#             "spl",
#             "wifi"
#         ],
#         "hours": {
#             "status": "Closed until 10:00 AM tomorrow",
#             "timeframes": [
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "10:00 AM\u20138:00 PM"
#                         }
#                     ],
#                     "days": "Mon\u2013Thu",
#                     "includesToday": true
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "10:00 AM\u20136:00 PM"
#                         }
#                     ],
#                     "days": "Fri\u2013Sat"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "Noon\u20136:00 PM"
#                         }
#                     ],
#                     "days": "Sun"
#                 }
#             ],
#             "isLocalHoliday": false,
#             "isOpen": false
#         },
#         "photos": {
#             "count": 1654,
#             "groups": [
#                 {
#                     "count": 1654,
#                     "items": [
#                         {
#                             "suffix": "/16720239_VKZ_4tjfwz8_pLF6HaKffNW9NFZC8tMx6bxec_QAh0w.jpg",
#                             "width": 717,
#                             "visibility": "public",
#                             "height": 959,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs0.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "DongHo",
#                                 "lastName": "Na",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/I5YPJQH3GCRMBXPX.png"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "16720239"
#                             },
#                             "id": "51c61841498e7baf21719fe3",
#                             "createdAt": 1371936833
#                         },
#                         {
#                             "suffix": "/777003_RephLy0KpoIMGwDZBDzQgpVr3bUkcJkQXAoASvFRaIY.jpg",
#                             "width": 612,
#                             "visibility": "public",
#                             "height": 612,
#                             "source": {
#                                 "url": "http://instagram.com",
#                                 "name": "Instagram"
#                             },
#                             "prefix": "https://irs1.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Jtkv",
#                                 "lastName": "Koh",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/HNIT43GC2TVQY5NY.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "777003"
#                             },
#                             "id": "506c9223e4b06dd5bb45e7ea",
#                             "createdAt": 1349292579
#                         },
#                         {
#                             "suffix": "/ET8Ipg58KokzFCt43slL8x_dV5GG1-n6Gjnio2uawvA.jpg",
#                             "width": 540,
#                             "visibility": "public",
#                             "height": 540,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs2.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "male",
#                                 "isAnonymous": false,
#                                 "id": "1149",
#                                 "firstName": "Stills",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/NCCJZP4B5YG3D2R3.jpg"
#                                 }
#                             },
#                             "id": "4fd2737de4b0b56918586f67",
#                             "createdAt": 1339192189
#                         },
#                         {
#                             "suffix": "/644595_VpvSx69-6ROAMD96ADoVXhnlHCus7xHBUihFrk_g-ls.jpg",
#                             "width": 612,
#                             "visibility": "public",
#                             "height": 612,
#                             "source": {
#                                 "url": "http://instagram.com",
#                                 "name": "Instagram"
#                             },
#                             "prefix": "https://irs1.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Bianca",
#                                 "lastName": "Smith",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/N1EKQATNUNJTHXBP.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "644595"
#                             },
#                             "id": "51af9bdb498ee77f91c17575",
#                             "createdAt": 1370463195
#                         },
#                         {
#                             "suffix": "/2995696_BXQEWoFaWEIVfJGjS508YAJBvtKTg7Ee4zKrLgH33IY.jpg",
#                             "width": 960,
#                             "visibility": "public",
#                             "height": 720,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs0.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "male",
#                                 "isAnonymous": false,
#                                 "id": "2995696",
#                                 "firstName": "Sander van Lingen",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/2995696-VQEDT0YSNFXOQXEC.jpg"
#                                 }
#                             },
#                             "id": "5160ac53e4b040ebb4b009ea",
#                             "createdAt": 1365290067
#                         },
#                         {
#                             "suffix": "/1996610_jamVLnnlmpuG0IREx4_HxO6UVGlFfOEUQciy2yQj_4E.jpg",
#                             "width": 720,
#                             "visibility": "public",
#                             "height": 960,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs2.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Rick",
#                                 "lastName": "Gordon",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/CHG3ODC1E1UZR4NO.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "1996610"
#                             },
#                             "id": "51ca29a5498e6311d25b6a27",
#                             "createdAt": 1372203429
#                         }
#                     ],
#                     "type": "venue",
#                     "name": "Venue photos"
#                 }
#             ]
#         },
#         "attributes": {
#             "groups": [
#                 {
#                     "count": 1,
#                     "items": [
#                         {
#                             "displayValue": "Yes",
#                             "displayName": "Wi-Fi"
#                         }
#                     ],
#                     "type": "wifi",
#                     "name": "Wi-Fi",
#                     "summary": "Wi-Fi"
#                 }
#             ]
#         },
#         "stats": {
#             "tipCount": 141,
#             "checkinsCount": 24771,
#             "visitsCount": 31972,
#             "usersCount": 14711
#         },
#         "tips": {
#             "count": 141,
#             "groups": [
#                 {
#                     "count": 141,
#                     "items": [
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 96
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4ccaf04d52af9c74d9d1a864",
#                             "agreeCount": 33,
#                             "text": "Stand at the corner of 5th and Spring, across from the library, to capture the entire building.  A reflection of the sunset on the building is possible from late spring to early summer.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 33,
#                                 "groups": [
#                                     {
#                                         "count": 33,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "33 likes"
#                             },
#                             "type": "user",
#                             "id": "4ccaf04d52af9c74d9d1a864",
#                             "createdAt": 1288368205,
#                             "user": {
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/EO14EVSDDROIXRTL.png"
#                                 },
#                                 "firstName": "Windows Live Photo Gallery",
#                                 "gender": "none",
#                                 "type": "page",
#                                 "isAnonymous": false,
#                                 "id": "3052639"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4c3b70694565e21e91ba566a",
#                             "agreeCount": 1,
#                             "text": "Explore the whole library! It's so cool!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 13,
#                                 "groups": [
#                                     {
#                                         "count": 13,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "13 likes"
#                             },
#                             "type": "user",
#                             "id": "4c3b70694565e21e91ba566a",
#                             "createdAt": 1278963817,
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Sandy",
#                                 "lastName": "Whittington",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/1792738-0KHBTKWNPMCK1TFG.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "1792738"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 1
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4b8ea5f570c603bba27793b4",
#                             "agreeCount": 2,
#                             "text": "Amazing architecture.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 13,
#                                 "groups": [
#                                     {
#                                         "count": 13,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "13 likes"
#                             },
#                             "type": "user",
#                             "id": "4b8ea5f570c603bba27793b4",
#                             "createdAt": 1267639797,
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Brian",
#                                 "lastName": "Hansford",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/TGNNAU5ATDLK4ZP3.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "341332"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4bfc7f9770c603bb4efc9cb4",
#                             "agreeCount": 3,
#                             "text": "Read a book",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 12,
#                                 "groups": [
#                                     {
#                                         "count": 12,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "12 likes"
#                             },
#                             "type": "user",
#                             "id": "4bfc7f9770c603bb4efc9cb4",
#                             "createdAt": 1274838935,
#                             "user": {
#                                 "gender": "none",
#                                 "firstName": "Christopher Michael",
#                                 "lastName": "Shumaker",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/OMSSPUVCNFUUSHYI.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "1377689"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 1
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4b4ca54270c603bbde7490b4",
#                             "agreeCount": 4,
#                             "url": "http://www.spl.org",
#                             "text": "One of the coolest spots in downtown Seattle.  And it's free!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 12,
#                                 "groups": [
#                                     {
#                                         "count": 12,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "12 likes"
#                             },
#                             "type": "user",
#                             "id": "4b4ca54270c603bbde7490b4",
#                             "createdAt": 1263314242,
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Pat",
#                                 "lastName": "Bingaman",
#                                 "photo": {
#                                     "default": true,
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/blank_boy.png"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "224891"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4f0b3675e4b071c5784f9fc7",
#                             "agreeCount": 2,
#                             "text": "UCSD's Geisel Library can't hold a dime to this!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 11,
#                                 "groups": [
#                                     {
#                                         "count": 11,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "11 likes"
#                             },
#                             "type": "user",
#                             "id": "4f0b3675e4b071c5784f9fc7",
#                             "createdAt": 1326134901,
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Carolyn",
#                                 "lastName": "Kao",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/QFILI1ONZTXFOQST.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "516154"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 1
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4d1bd1771356224bf9640abe",
#                             "agreeCount": 10,
#                             "text": "Enjoy the bright lime-colored escalators.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 10,
#                                 "groups": [
#                                     {
#                                         "count": 10,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "10 likes"
#                             },
#                             "type": "user",
#                             "id": "4d1bd1771356224bf9640abe",
#                             "createdAt": 1293668727,
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Jeff",
#                                 "lastName": "W",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/35KHZCHBYHHFDMBV.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "20057"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4b60cc0470c603bb59f690b4",
#                             "agreeCount": 1,
#                             "text": "Take pictures on the evil red 4th floor. Bonus: Get a job and work here.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 8,
#                                 "groups": [
#                                     {
#                                         "count": 8,
#                                         "items": [
#                                             {
#                                                 "gender": "male",
#                                                 "firstName": "Tyler",
#                                                 "lastName": "Bosma",
#                                                 "photo": {
#                                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                                     "suffix": "/DLR545P1ZQ2M1JRO.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "6868828"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "8 likes"
#                             },
#                             "type": "user",
#                             "id": "4b60cc0470c603bb59f690b4",
#                             "createdAt": 1264634884,
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Shawn",
#                                 "lastName": "Delaney",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/BYLAYCTHU2BWG02Q.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "313071"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4da85b18ffcb3bd52b106b1b",
#                             "agreeCount": 7,
#                             "text": "Marvel at this Rem Koolhaas-designed public library, from its airy and bright steel and glass structure to its towering non-fiction book spiral and vibrant magenta and lime children's reading room.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 7,
#                                 "groups": [
#                                     {
#                                         "count": 7,
#                                         "items": [
#                                             {
#                                                 "gender": "male",
#                                                 "firstName": "Haonan",
#                                                 "lastName": "Zhang",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/5I3C1GREKFCTRYLZ.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "243116"
#                                             },
#                                             {
#                                                 "gender": "female",
#                                                 "firstName": "Lailanie",
#                                                 "lastName": "Gadia",
#                                                 "photo": {
#                                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                                     "suffix": "/32568130-Z2ORATI5KWBVEP5Z.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "32568130"
#                                             },
#                                             {
#                                                 "gender": "female",
#                                                 "firstName": "Judy",
#                                                 "lastName": "P",
#                                                 "photo": {
#                                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                                     "suffix": "/ARUB30FSKGU2FQC0.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "8480704"
#                                             },
#                                             {
#                                                 "gender": "male",
#                                                 "firstName": "Joe",
#                                                 "lastName": "Do",
#                                                 "photo": {
#                                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                                     "suffix": "/DL0FABOBU04VMUHQ.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "14828298"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "7 likes"
#                             },
#                             "type": "user",
#                             "id": "4da85b18ffcb3bd52b106b1b",
#                             "createdAt": 1302879000,
#                             "user": {
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/K2SFYF2XR23VVNCD.jpg"
#                                 },
#                                 "firstName": "ToryBurch",
#                                 "gender": "none",
#                                 "type": "chain",
#                                 "isAnonymous": false,
#                                 "id": "2213075"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4ce323444df7a35d9449e179",
#                             "agreeCount": 6,
#                             "text": "Used the spl app to reserve books from my list a few days ago and the used it as my library card to check them out lightning fast today!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 7,
#                                 "groups": [
#                                     {
#                                         "count": 7,
#                                         "items": [
#                                             {
#                                                 "gender": "male",
#                                                 "firstName": "Luis",
#                                                 "lastName": "R",
#                                                 "photo": {
# ...
#                                                 "lastName": "Jack\u26f5",
#                                                 "photo": {
#                                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                                     "suffix": "/IOJNBJZHZN03VS4X.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "4461818"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "3 likes"
#                             },
#                             "text": "You haven't filed for your taxes, and need help? The United Way is offering assistance to doing your taxes. The will even eFile your return. They also have service for basic needs.",
#                             "type": "user",
#                             "id": "5148d86ee4b0ce7914d22930",
#                             "createdAt": 1363728494,
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "\u26f5Captain",
#                                 "lastName": "Jack\u26f5",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/IOJNBJZHZN03VS4X.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "4461818"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 1
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/503fef61e4b05e5c0ea582dc",
#                             "agreeCount": 3,
#                             "text": "Across the street is a great restaurant -  Sazerac that is part of the Kimpton Hotel that serves perfect soft boiled eggs. Rare find.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 3,
#                                 "groups": [
#                                     {
#                                         "count": 3,
#                                         "items": [
#                                             {
#                                                 "gender": "male",
#                                                 "firstName": "Tibor",
#                                                 "lastName": "Szentmarjay",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/ILOCSSJHNLGEJGME.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "858251"
#                                             },
#                                             {
#                                                 "gender": "female",
#                                                 "isAnonymous": false,
#                                                 "id": "20089145",
#                                                 "firstName": "Irina",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/20089145-42ZRW4XQ132CMMKB.jpg"
#                                                 }
#                                             },
#                                             {
#                                                 "gender": "male",
#                                                 "firstName": "Mike",
#                                                 "lastName": "D",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/I4HZGKHA1V3ZFQOL.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "4761739"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "3 likes"
#                             },
#                             "type": "user",
#                             "id": "503fef61e4b05e5c0ea582dc",
#                             "createdAt": 1346367329,
#                             "user": {
#                                 "gender": "none",
#                                 "isAnonymous": false,
#                                 "id": "6997641",
#                                 "firstName": "Mel",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/LNMUXBHFF4QNIOKX.jpg"
#                                 }
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/502d4d01e4b0504d9d5bb1f3",
#                             "photourl": "https://irs1.4sqi.net/img/general/original/ThCas71f0JZVJ_RX1Os8-pGEoObOtrJKsRl8LYxw8Hg.jpg",
#                             "photo": {
#                                 "suffix": "/ThCas71f0JZVJ_RX1Os8-pGEoObOtrJKsRl8LYxw8Hg.jpg",
#                                 "width": 720,
#                                 "visibility": "public",
#                                 "height": 406,
#                                 "source": {
#                                     "url": "https://foursquare.com/download/#/android",
#                                     "name": "Foursquare for Android"
#                                 },
#                                 "prefix": "https://irs1.4sqi.net/img/general/",
#                                 "id": "502d4d04e4b0260c90dad708",
#                                 "createdAt": 1345146116
#                             },
#                             "agreeCount": 3,
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 3,
#                                 "groups": [
#                                     {
#                                         "count": 3,
#                                         "items": [
#                                             {
#                                                 "gender": "male",
#                                                 "firstName": "Haonan",
#                                                 "lastName": "Zhang",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/5I3C1GREKFCTRYLZ.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "243116"
#                                             },
#                                             {
#                                                 "gender": "male",
#                                                 "firstName": "Kushal",
#                                                 "lastName": "Dave",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/2102_1242573242.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "2102"
#                                             },
#                                             {
#                                                 "gender": "female",
#                                                 "isAnonymous": false,
#                                                 "id": "20089145",
#                                                 "firstName": "Irina",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/20089145-42ZRW4XQ132CMMKB.jpg"
#                                                 }
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "3 likes"
#                             },
#                             "text": "There is a free self-guided cell phone tour throughout the library. Fun fact: the public art outside the meeting rooms on the 4th floor is excerpts from Robert's Rulesand of Order.",
#                             "type": "user",
#                             "id": "502d4d01e4b0504d9d5bb1f3",
#                             "createdAt": 1345146113,
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Sarah",
#                                 "lastName": "Malloy-Good",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/JPXRY51IQ5JL0CNF.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "13158438"
#                             }
#                         }
#                     ],
#                     "type": "others",
#                     "name": "All tips"
#                 }
#             ]
#         },
#         "categories": [
#             {
#                 "pluralName": "Libraries",
#                 "primary": true,
#                 "name": "Library",
#                 "shortName": "Library",
#                 "id": "4bf58dd8d48988d12f941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/building/library_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "ok": false,
#         "name": "Seattle Public Library (Seattle Central Library)",
#         "url": "http://www.spl.org/locations/central-library",
#         "phrases": [
#             {
#                 "sample": {
#                     "entities": [
#                         {
#                             "indices": [
#                                 0,
#                                 20
#                             ],
#                             "type": "keyPhrase"
#                         }
#                     ],
#                     "text": "Amazing architecture and design!"
#                 },
#                 "phrase": "amazing architecture",
#                 "count": 4
#             },
#             {
#                 "sample": {
#                     "entities": [
#                         {
#                             "indices": [
#                                 24,
#                                 34
#                             ],
#                             "type": "keyPhrase"
#                         }
#                     ],
#                     "text": "... place to work from. 10th floor"
#                 },
#                 "phrase": "10th floor",
#                 "count": 6
#             },
#             {
#                 "sample": {
#                     "entities": [
#                         {
#                             "indices": [
#                                 26,
#                                 38
#                             ],
#                             "type": "keyPhrase"
#                         }
#                     ],
#                     "text": "... the library downtown. Rem Koolhaas is a visionary."
#                 },
#                 "phrase": "rem koolhaas",
#                 "count": 3
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "venueChains": [],
#         "ratingColor": "00B551",
#         "ratingSignals": 559,
#         "popular": {
#             "timeframes": [
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "10:00 AM\u20137:00 PM"
#                         }
#                     ],
#                     "days": "Today",
#                     "includesToday": true
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "10:00 AM\u20137:00 PM"
#                         }
#                     ],
#                     "days": "Wed\u2013Thu"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "10:00 AM\u20136:00 PM"
#                         }
#                     ],
#                     "days": "Fri\u2013Sat"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "Noon\u20136:00 PM"
#                         }
#                     ],
#                     "days": "Sun"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "10:00 AM\u20137:00 PM"
#                         }
#                     ],
#                     "days": "Mon"
#                 }
#             ],
#             "isLocalHoliday": false,
#             "isOpen": false
#         },
#         "timeZone": "America/Los_Angeles",
#         "page": {
#             "user": {
#                 "bio": "",
#                 "firstName": "Seattle Public Library",
#                 "gender": "none",
#                 "venue": {
#                     "id": "42a78680f964a52011251fe3"
#                 },
#                 "lists": {
#                     "groups": [
#                         {
#                             "count": 2,
#                             "items": [],
#                             "type": "created"
#                         }
#                     ]
#                 },
#                 "homeCity": "Seattle, WA",
#                 "contact": {},
#                 "photo": {
#                     "prefix": "https://irs3.4sqi.net/img/user/",
#                     "suffix": "/78244976-ERQ3GIZOYYJJTN3K.png"
#                 },
#                 "isAnonymous": false,
#                 "tips": {
#                     "count": 0
#                 },
#                 "type": "venuePage",
#                 "id": "78244976"
#             }
#         },
#         "inbox": {
#             "count": 0,
#             "items": []
#         }
#     }
# }

# %% [markdown]
# Create a procedure that will only extract the comments in a list. There are a few ways you can do this, but I highly recommend you look up the map method from the base Python library: https://docs.python.org/2/tutorial/datastructures.html
#
# This is the same "map" function, that's one part of the map-reduce duo used in "Big Data" applications. So it may be helpful to get familiar with this method now if that's where you think you may want to take your career in the future.

# %%
map(lambda h: h['text'], temp1['venue']['tips']['groups'][0]['items'])
# Out:
# [u'Stand at the corner of 5th and Spring, across from the library, to capture the entire building.  A reflection of the sunset on the building is possible from late spring to early summer.',
#  u"Explore the whole library! It's so cool!",
#  u'Amazing architecture.',
#  u'Read a book',
#  u"One of the coolest spots in downtown Seattle.  And it's free!",
#  u"UCSD's Geisel Library can't hold a dime to this!",
#  u'Enjoy the bright lime-colored escalators.',
#  u'Take pictures on the evil red 4th floor. Bonus: Get a job and work here.',
#  u"Marvel at this Rem Koolhaas-designed public library, from its airy and bright steel and glass structure to its towering non-fiction book spiral and vibrant magenta and lime children's reading room.",
#  u'Used the spl app to reserve books from my list a few days ago and the used it as my library card to check them out lightning fast today!',
#  u'parking  underground off Spring St',
#  u'Best tip/tool ever. The directory on your phone.',
#  u'Check out a book (or a comic book or a CD or a DVD) from one of the best - and most beautiful - libraries in the Americas.',
#  u'From the 10th floor, walk past the elevators and around the corner. Watch the movie projected to the side of the lower floors as you look down to the 2nd floor stacks. This place is a treasure trove.',
#  u'Amazing Public Library designed by Internationally renown architect Rem Koolhaas',
#  u'Those hooks you see hanging below the windows on the top floor are for window washers. *faints*',
#  u"From the upper floors, you get a great bird's eye view of practically the entire city. In fact, the view's so great, you see things you shouldn't. Like that time we saw a couple boning on a rooftop.",
#  u"You haven't filed for your taxes, and need help? The United Way is offering assistance to doing your taxes. The will even eFile your return. They also have service for basic needs.",
#  u'Across the street is a great restaurant -  Sazerac that is part of the Kimpton Hotel that serves perfect soft boiled eggs. Rare find.',
#  u"There is a free self-guided cell phone tour throughout the library. Fun fact: the public art outside the meeting rooms on the 4th floor is excerpts from Robert's Rulesand of Order."]

# %% [markdown]
# Now we're going to bring the above mini-tasks together into a nice little method, that will allow us to convert any foursquare JSON data into a nice tabular / rectangular table for further analysis. First instnatiate a pandas data frame.

# %% [markdown]
# Write a procedure that will take your list of venues around a certain geography/lat/long whatever, and output a table that will have for each row, a comment associated for the venue (multiple comments will mean multiple rows, each per comment), the venue name, the tip count, the user count, and the store category. Make sure that each column is populated with appropriately typed values, i.e. names/categories should be strings, and numbers should be numerical data type.

# %% [markdown]
# **Hint**: Before you begin, think about the process. You're going to start with a loop of some kind, then think about the following:
# - How many of those do you need?
# - Think about the JSON structure, how "deep" do you need to penetrate the hierarchy to reach the data you want (this will help you think about how many loops you need for your crawler
# - How should you iteratively add on to your Pandas data frame?
# - Think of any tests you may need to put in to ensure your procedure does not cause an error (this may help you figure out how many if statements you may need, and where to place them.

# %%
def city_venues(city):
    venues = pd.DataFrame()
    venues_list = client.venues.search(params={'near': city, 'intent': 'browse'})
    for i in range(len(venues_list['venues'])):
        ven_id = venues_list['venues'][i]['id'].encode('ascii', 'ignore')
        ven = client.venues(temp)
        mini_df = pd.DataFrame()
        mini_df['Comments'] = map(lambda h: h['text'].encode('ascii', 'ignore'), ven['venue']['tips']['groups'][0]['items'])
        mini_df['Venue_Name'] = venues_list['venues'][i]['name'].encode('ascii', 'ignore')
        mini_df['Tip_Count'] = ven['venue']['stats']['tipCount']
        mini_df['User_Count'] = ven['venue']['stats']['usersCount']
        if (venues_list['venues'][i]['categories']) != []:
            mini_df['Category'] = venues_list['venues'][i]['categories'][0]['name'].encode('ascii', 'ignore')
        else:
            mini_df['Category'] = "No Category"
        venues = pd.concat([venues, mini_df])
    return venues.reset_index(drop=True)

# %%
seattle_venues = city_venues('Seattle, WA')

# %% [markdown]
# You've done it! You've built a simple crawler that traverses a JSON directory, and you've deposited the results in a nice Pandas data frame. Congratulations! You're now ready for more data-mining in the future, and have just beefed up the **data** part of the data science combination :)

# %%
seattle_venues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 5 columns):
# Comments      600 non-null object
# Venue_Name    600 non-null object
# Tip_Count     600 non-null int64
# User_Count    600 non-null int64
# Category      600 non-null object
# dtypes: int64(2), object(3)
# memory usage: 23.5+ KB

# %%
seattle_venues
# Out:
#                                               Comments  \
# 0    Stand at the corner of 5th and Spring, across ...
# 1             Explore the whole library! It's so cool!
# 2                                Amazing architecture.
# 3                                          Read a book
# 4    One of the coolest spots in downtown Seattle. ...
# 5     UCSD's Geisel Library can't hold a dime to this!
# 6            Enjoy the bright lime-colored escalators.
# 7    Take pictures on the evil red 4th floor. Bonus...
# 8    Marvel at this Rem Koolhaas-designed public li...
# 9    Used the spl app to reserve books from my list...
# 10                  parking  underground off Spring St
# 11    Best tip/tool ever. The directory on your phone.
# 12   Check out a book (or a comic book or a CD or a...
# 13   From the 10th floor, walk past the elevators a...
# 14   Amazing Public Library designed by Internation...
# 15   Those hooks you see hanging below the windows ...
# 16   From the upper floors, you get a great bird's ...
# 17   You haven't filed for your taxes, and need hel...
# 18   Across the street is a great restaurant -  Saz...
# 19   There is a free self-guided cell phone tour th...
# 20   Stand at the corner of 5th and Spring, across ...
# 21            Explore the whole library! It's so cool!
# 22                               Amazing architecture.
# 23                                         Read a book
# 24   One of the coolest spots in downtown Seattle. ...
# 25    UCSD's Geisel Library can't hold a dime to this!
# 26           Enjoy the bright lime-colored escalators.
# 27   Take pictures on the evil red 4th floor. Bonus...
# 28   Marvel at this Rem Koolhaas-designed public li...
# 29   Used the spl app to reserve books from my list...
# ..                                                 ...
# 570                 parking  underground off Spring St
# 571   Best tip/tool ever. The directory on your phone.
# 572  Check out a book (or a comic book or a CD or a...
# 573  From the 10th floor, walk past the elevators a...
# 574  Amazing Public Library designed by Internation...
# 575  Those hooks you see hanging below the windows ...
# 576  From the upper floors, you get a great bird's ...
# 577  You haven't filed for your taxes, and need hel...
# 578  Across the street is a great restaurant -  Saz...
# 579  There is a free self-guided cell phone tour th...
# 580  Stand at the corner of 5th and Spring, across ...
# 581           Explore the whole library! It's so cool!
# 582                              Amazing architecture.
# 583                                        Read a book
# 584  One of the coolest spots in downtown Seattle. ...
# 585   UCSD's Geisel Library can't hold a dime to this!
# 586          Enjoy the bright lime-colored escalators.
# 587  Take pictures on the evil red 4th floor. Bonus...
# 588  Marvel at this Rem Koolhaas-designed public li...
# 589  Used the spl app to reserve books from my list...
# 590                 parking  underground off Spring St
# 591   Best tip/tool ever. The directory on your phone.
# 592  Check out a book (or a comic book or a CD or a...
# 593  From the 10th floor, walk past the elevators a...
# 594  Amazing Public Library designed by Internation...
# 595  Those hooks you see hanging below the windows ...
# 596  From the upper floors, you get a great bird's ...
# 597  You haven't filed for your taxes, and need hel...
# 598  Across the street is a great restaurant -  Saz...
# 599  There is a free self-guided cell phone tour th...
#
#                                            Venue_Name  Tip_Count  User_Count  \
# 0    Seattle Public Library (Seattle Central Library)        141       14711
# 1    Seattle Public Library (Seattle Central Library)        141       14711
# 2    Seattle Public Library (Seattle Central Library)        141       14711
# 3    Seattle Public Library (Seattle Central Library)        141       14711
# 4    Seattle Public Library (Seattle Central Library)        141       14711
# 5    Seattle Public Library (Seattle Central Library)        141       14711
# 6    Seattle Public Library (Seattle Central Library)        141       14711
# 7    Seattle Public Library (Seattle Central Library)        141       14711
# 8    Seattle Public Library (Seattle Central Library)        141       14711
# 9    Seattle Public Library (Seattle Central Library)        141       14711
# 10   Seattle Public Library (Seattle Central Library)        141       14711
# 11   Seattle Public Library (Seattle Central Library)        141       14711
# 12   Seattle Public Library (Seattle Central Library)        141       14711
# 13   Seattle Public Library (Seattle Central Library)        141       14711
# 14   Seattle Public Library (Seattle Central Library)        141       14711
# 15   Seattle Public Library (Seattle Central Library)        141       14711
# 16   Seattle Public Library (Seattle Central Library)        141       14711
# 17   Seattle Public Library (Seattle Central Library)        141       14711
# 18   Seattle Public Library (Seattle Central Library)        141       14711
# 19   Seattle Public Library (Seattle Central Library)        141       14711
# 20                          Renaissance Seattle Hotel        141       14711
# 21                          Renaissance Seattle Hotel        141       14711
# 22                          Renaissance Seattle Hotel        141       14711
# 23                          Renaissance Seattle Hotel        141       14711
# 24                          Renaissance Seattle Hotel        141       14711
# 25                          Renaissance Seattle Hotel        141       14711
# 26                          Renaissance Seattle Hotel        141       14711
# 27                          Renaissance Seattle Hotel        141       14711
# 28                          Renaissance Seattle Hotel        141       14711
# 29                          Renaissance Seattle Hotel        141       14711
# ..                                                ...        ...         ...
# 570                              Maxwell's Restaurant        141       14711
# 571                              Maxwell's Restaurant        141       14711
# 572                              Maxwell's Restaurant        141       14711
# 573                              Maxwell's Restaurant        141       14711
# 574                              Maxwell's Restaurant        141       14711
# 575                              Maxwell's Restaurant        141       14711
# 576                              Maxwell's Restaurant        141       14711
# 577                              Maxwell's Restaurant        141       14711
# 578                              Maxwell's Restaurant        141       14711
# 579                              Maxwell's Restaurant        141       14711
# 580                              Microsoft Auditorium        141       14711
# 581                              Microsoft Auditorium        141       14711
# 582                              Microsoft Auditorium        141       14711
# 583                              Microsoft Auditorium        141       14711
# 584                              Microsoft Auditorium        141       14711
# 585                              Microsoft Auditorium        141       14711
# 586                              Microsoft Auditorium        141       14711
# 587                              Microsoft Auditorium        141       14711
# 588                              Microsoft Auditorium        141       14711
# 589                              Microsoft Auditorium        141       14711
# 590                              Microsoft Auditorium        141       14711
# 591                              Microsoft Auditorium        141       14711
# 592                              Microsoft Auditorium        141       14711
# 593                              Microsoft Auditorium        141       14711
# 594                              Microsoft Auditorium        141       14711
# 595                              Microsoft Auditorium        141       14711
# 596                              Microsoft Auditorium        141       14711
# 597                              Microsoft Auditorium        141       14711
# 598                              Microsoft Auditorium        141       14711
# 599                              Microsoft Auditorium        141       14711
#
#                 Category
# 0                Library
# 1                Library
# 2                Library
# 3                Library
# 4                Library
# 5                Library
# 6                Library
# 7                Library
# 8                Library
# 9                Library
# 10               Library
# 11               Library
# 12               Library
# 13               Library
# 14               Library
# 15               Library
# 16               Library
# 17               Library
# 18               Library
# 19               Library
# 20                 Hotel
# 21                 Hotel
# 22                 Hotel
# 23                 Hotel
# 24                 Hotel
# 25                 Hotel
# 26                 Hotel
# 27                 Hotel
# 28                 Hotel
# 29                 Hotel
# ..                   ...
# 570  American Restaurant
# 571  American Restaurant
# 572  American Restaurant
# 573  American Restaurant
# 574  American Restaurant
# 575  American Restaurant
# 576  American Restaurant
# 577  American Restaurant
# 578  American Restaurant
# 579  American Restaurant
# 580           Auditorium
# 581           Auditorium
# 582           Auditorium
# 583           Auditorium
# 584           Auditorium
# 585           Auditorium
# 586           Auditorium
# 587           Auditorium
# 588           Auditorium
# 589           Auditorium
# 590           Auditorium
# 591           Auditorium
# 592           Auditorium
# 593           Auditorium
# 594           Auditorium
# 595           Auditorium
# 596           Auditorium
# 597           Auditorium
# 598           Auditorium
# 599           Auditorium
#
# [600 rows x 5 columns]
