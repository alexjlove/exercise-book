# %%
# !pip install bokeh --upgrade
# Out:
# Collecting bokeh
#   Downloading bokeh-0.12.2.zip (4.0MB)
#     100% |████████████████████████████████| 4.0MB 248kB/s
# Requirement already up-to-date: six>=1.5.2 in /home/useraj/anaconda2/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: requests>=1.2.3 in /home/useraj/anaconda2/lib/python2.7/site-packages (from bokeh)
# Collecting PyYAML>=3.10 (from bokeh)
#   Downloading PyYAML-3.12.tar.gz (253kB)
#     100% |████████████████████████████████| 256kB 2.9MB/s
# Requirement already up-to-date: python-dateutil>=2.1 in /home/useraj/anaconda2/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: Jinja2>=2.7 in /home/useraj/anaconda2/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: numpy>=1.7.1 in /home/useraj/anaconda2/lib/python2.7/site-packages (from bokeh)
# Collecting tornado>=4.3 (from bokeh)
#   Downloading tornado-4.4.1.tar.gz (456kB)
#     100% |████████████████████████████████| 460kB 1.2MB/s
# Requirement already up-to-date: futures>=3.0.3 in /home/useraj/anaconda2/lib/python2.7/site-packages (from bokeh)
# Requirement already up-to-date: MarkupSafe in /home/useraj/anaconda2/lib/python2.7/site-packages (from Jinja2>=2.7->bokeh)
# Requirement already up-to-date: singledispatch in /home/useraj/anaconda2/lib/python2.7/site-packages (from tornado>=4.3->bokeh)
# Collecting certifi (from tornado>=4.3->bokeh)
#   Downloading certifi-2016.9.26-py2.py3-none-any.whl (377kB)
#     100% |████████████████████████████████| 378kB 1.8MB/s
# Requirement already up-to-date: backports_abc>=0.4 in /home/useraj/anaconda2/lib/python2.7/site-packages (from tornado>=4.3->bokeh)
# Building wheels for collected packages: bokeh, PyYAML, tornado
# done
#   Stored in directory: /home/useraj/.cache/pip/wheels/b2/88/90/5e0be73ef8398c1bfbc215f0566482b64ac8aa273b82742bd1
# done
#   Stored in directory: /home/useraj/.cache/pip/wheels/2c/f7/79/13f3a12cd723892437c0cfbde1230ab4d82947ff7b3839a4fc
# done
#   Stored in directory: /home/useraj/.cache/pip/wheels/c2/65/99/727ea73b981e0ef1fb8ab678ecf86f39c809230f5301ac3a40
# Successfully built bokeh PyYAML tornado
# Installing collected packages: PyYAML, certifi, tornado, bokeh
#   Found existing installation: PyYAML 3.11
#     DEPRECATION: Uninstalling a distutils installed project (PyYAML) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling PyYAML-3.11:
#       Successfully uninstalled PyYAML-3.11
#   Found existing installation: tornado 4.3
#     DEPRECATION: Uninstalling a distutils installed project (tornado) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling tornado-4.3:
#       Successfully uninstalled tornado-4.3
#   Found existing installation: bokeh 0.12.0
#     DEPRECATION: Uninstalling a distutils installed project (bokeh) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling bokeh-0.12.0:
#       Successfully uninstalled bokeh-0.12.0
# Successfully installed PyYAML-3.12 bokeh-0.12.2 certifi-2016.9.26 tornado-4.4.1

# %%
import bokeh

# %% [markdown]
# * bokeh.models #low-level interface
# * bokeh.plotting # medium
# * bokeh.charts #high-level interface

# %%
from bokeh.charts import Scatter, output_notebook, show
import pandas as pd

# %%
df = pd.DataFrame(columns=["X", "Y"])
df["X"] = [1,2,3,4,5]
df["Y"] = [6,4,2,9,5]
df
# Out:
#    X  Y
# 0  1  6
# 1  2  4
# 2  3  2
# 3  4  9
# 4  5  5

# %%
p = Scatter(df, x="X", y="Y",
            title="Temperature Observations",
            xlabel="Day of Observation",
            ylabel="Temperature",
            tools='pan, resize')

p.toolbar.logo = None

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9226f6dc-0a53-42d2-a219-0dcf75ae5f40">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="882be13c-d3ed-4cce-9855-0fb72b3f8fd0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#882be13c-d3ed-4cce-9855-0fb72b3f8fd0").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("882be13c-d3ed-4cce-9855-0fb72b3f8fd0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '882be13c-d3ed-4cce-9855-0fb72b3f8fd0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ffbbe395-8e33-4871-9ba0-24ef44ecdade":{"roots":{"references":[{"attributes":{"data_source":{"id":"3637c295-d8cf-4b93-a0ae-a5cdc504ab85","type":"ColumnDataSource"},"glyph":{"id":"20181df9-380a-4138-8341-071cdc1b4f98","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ab116f68-4c45-42d9-8514-0634745eaa04","type":"GlyphRenderer"},{"attributes":{},"id":"0daa9365-1ec6-47bb-b92f-753210750cb5","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Day of Observation","formatter":{"id":"2a4866cf-9e6c-4268-a42f-e057bbaf5096","type":"BasicTickFormatter"},"plot":{"id":"8abce18a-dda5-4cb3-96f6-ed4c72f507cc","subtype":"Chart","type":"Plot"},"ticker":{"id":"156dbcac-38ea-44d2-b4aa-73d11241e0ac","type":"BasicTicker"}},"id":"ca47171c-6271-4242-9854-72fa1b940e28","type":"LinearAxis"},{"attributes":{},"id":"74e1507c-7a6c-4aac-9eb0-7fd4bfb96f3b","type":"ToolEvents"},{"attributes":{},"id":"156dbcac-38ea-44d2-b4aa-73d11241e0ac","type":"BasicTicker"},{"attributes":{"callback":null,"end":5.4,"start":0.6},"id":"4dc7d602-9ec9-4666-953c-3c532e3952d9","type":"Range1d"},{"attributes":{"plot":{"id":"8abce18a-dda5-4cb3-96f6-ed4c72f507cc","subtype":"Chart","type":"Plot"}},"id":"1b9fd80f-553a-4529-b090-52a2f89ff128","type":"ResizeTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","logo":null,"tools":[{"id":"7e862eda-462c-4a9f-8feb-477934c9aad8","type":"PanTool"},{"id":"1b9fd80f-553a-4529-b090-52a2f89ff128","type":"ResizeTool"}]},"id":"49cc82ac-6139-49ec-bfcb-994e76aa34e0","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null],"x_values":[1,2,3,4,5],"y_values":[6,4,2,9,5]}},"id":"3637c295-d8cf-4b93-a0ae-a5cdc504ab85","type":"ColumnDataSource"},{"attributes":{},"id":"ee24ae76-f267-4160-80b4-cfd84eab9a41","type":"BasicTicker"},{"attributes":{},"id":"2a4866cf-9e6c-4268-a42f-e057bbaf5096","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Temperature Observations"},"id":"74f90092-ab6d-4fab-9b47-201bd7e00130","type":"Title"},{"attributes":{"location":"top_left","plot":{"id":"8abce18a-dda5-4cb3-96f6-ed4c72f507cc","subtype":"Chart","type":"Plot"}},"id":"317f609c-e34c-4e2e-8b7f-340d959b0f49","type":"Legend"},{"attributes":{"plot":{"id":"8abce18a-dda5-4cb3-96f6-ed4c72f507cc","subtype":"Chart","type":"Plot"},"ticker":{"id":"156dbcac-38ea-44d2-b4aa-73d11241e0ac","type":"BasicTicker"}},"id":"f69acc6a-04c1-4614-9ffa-18e4a032f52f","type":"Grid"},{"attributes":{"callback":null,"end":9.7,"start":1.2999999999999998},"id":"853a2db9-bb77-4fa5-b28b-2e14dab9d300","type":"Range1d"},{"attributes":{"below":[{"id":"ca47171c-6271-4242-9854-72fa1b940e28","type":"LinearAxis"}],"left":[{"id":"8291d798-612a-4f45-ad4b-b2c53dc685da","type":"LinearAxis"}],"renderers":[{"id":"ab116f68-4c45-42d9-8514-0634745eaa04","type":"GlyphRenderer"},{"id":"317f609c-e34c-4e2e-8b7f-340d959b0f49","type":"Legend"},{"id":"ca47171c-6271-4242-9854-72fa1b940e28","type":"LinearAxis"},{"id":"8291d798-612a-4f45-ad4b-b2c53dc685da","type":"LinearAxis"},{"id":"f69acc6a-04c1-4614-9ffa-18e4a032f52f","type":"Grid"},{"id":"b1832ff2-c1bc-4106-a93b-aee4891d8713","type":"Grid"}],"title":{"id":"74f90092-ab6d-4fab-9b47-201bd7e00130","type":"Title"},"tool_events":{"id":"74e1507c-7a6c-4aac-9eb0-7fd4bfb96f3b","type":"ToolEvents"},"toolbar":{"id":"49cc82ac-6139-49ec-bfcb-994e76aa34e0","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"4dc7d602-9ec9-4666-953c-3c532e3952d9","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"853a2db9-bb77-4fa5-b28b-2e14dab9d300","type":"Range1d"}},"id":"8abce18a-dda5-4cb3-96f6-ed4c72f507cc","subtype":"Chart","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"8abce18a-dda5-4cb3-96f6-ed4c72f507cc","subtype":"Chart","type":"Plot"},"ticker":{"id":"ee24ae76-f267-4160-80b4-cfd84eab9a41","type":"BasicTicker"}},"id":"b1832ff2-c1bc-4106-a93b-aee4891d8713","type":"Grid"},{"attributes":{"plo ...

# %%
from bokeh.charts import output_file

p = Scatter(df, x="X", y="Y",
            title="Temperature Observations",
            xlabel="Day of Observation",
            ylabel="Temperature",
            tools='pan, resize')

p.toolbar.logo = None

output_file("scatter_charts.html")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1dd8a9c7-ce1f-4f7b-b482-22a47a6469f4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1dd8a9c7-ce1f-4f7b-b482-22a47a6469f4").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1dd8a9c7-ce1f-4f7b-b482-22a47a6469f4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1dd8a9c7-ce1f-4f7b-b482-22a47a6469f4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"38ab5ea4-1112-405f-bea5-36191a4eaa72":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto
-4717-8179-afa024942feb","type":"PanTool"},{"attributes":{"axis_label":"Day of Observation","formatter":{"id":"d5f8cd2c-d96b-4a9c-abcd-7d3aa1c16168","type":"BasicTickFormatter"},"plot":{"id":"0cba87bf-9e7e-47d4-9fbb-6e1885ae5f2c","subtype":"Chart","type":"Plot"},"ticker":{"id":"0cde5add-4ac0-409d-8b45-a23facd26dc4","type":"BasicTicker"}},"id":"3ef38669-851c-4892-80e6-e5d3db4e3cf6","type":"LinearAxis"},{"attributes":{"callback":null,"end":5.4,"start":0.6},"id":"c62c4488-baa8-4561-bfef-476f2da3cb6e","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"451ca1a4-8b0b-4faf-b859-9922d31b9fb8","type":"Circle"},{"attributes":{},"id":"4b8750b1-6228-473b-9d32-360b2e4f8083","type":"BasicTicker"},{"attributes":{"plot":{"id":"0cba87bf-9e7e-47d4-9fbb-6e1885ae5f2c","subtype":"Chart","type":"Plot"},"ticker":{"id":"0cde5add-4ac0-409d-8b45-a23facd26dc4","type":"BasicTicker"}},"id":"04f2dd29-8f67-4300-a4b7-33c033eb28e4","type":"Grid"},{"attributes":{"location":"top_ ...

# %%
from bokeh.plotting import figure, output_file, show

p = figure(plot_width=400, plot_height=400, title="Temperature Observations")

#p.circle([1,2,3,4,5], [9,2,6,2,5], size=12, color="red", alpha=0.5)
p.circle([1,2,3,4,5], [9,2,6,2,5], 
         size=[i*2 for i in [6,9,12,15,18]], 
         color="red", alpha=0.5)

p.triangle([1,2,3,4,5], [1,9,4,8,2], 
         size=[i*2 for i in [6,9,12,15,18]], 
         color="green", alpha=0.5)

output_file("scatter_plotting.html")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a1ae1e97-5716-4484-8172-34361ef5e0e4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a1ae1e97-5716-4484-8172-34361ef5e0e4").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a1ae1e97-5716-4484-8172-34361ef5e0e4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a1ae1e97-5716-4484-8172-34361ef5e0e4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9d5d508c-9e4f-4783-97e6-bf2397dffd40":{"roots":{"references":[{"attributes":{"plot":{"id":"7f05c6b0-c541-4c58-ab22-55d8ee21c83b","subtype":"Figure","type":"Plot"}},"id":"11fee4ef-8f61-438e-8550-563b1e91e649","type":"SaveTool"},{"attributes":{},"id":"21576e01-06f0-4495-aa98-838eaac608dd","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"7f05c6b0-c541-4c58-ab22-55d8ee21c83b","subtype":"Figure","type":"Plot"},"ticker":{"id":"21576e01-06f0-4495-aa98-838eaac608dd","type":"BasicTicker"}},"id":"5404b15c-cabd-4c0b-87be-a895c045ad27","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f4a5704-982e-4615-a26d-b61d148c3c12","type":"Triangle"},{"attributes":{"callback":null},"id":"531b2929-b034-4733-86f7-92d6a3a6a588","type":"DataRange1d"},{"attributes":{"callback":null},"id":"9293c0a6-89e7-4baf-92f8-f10bbb2ffee0","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e6d9cf4a-56da-446e-888f-e73a3f08f4ff","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"e6d9cf4a-56da-446e-888f-e73a3f08f4ff","type":"BoxAnnotation"},"plot":{"id":"7f05c6b0-c541-4c58-ab22-55d8ee21c83b","subtype":"Figure","type":"Plot"}},"id":"33d59e8c-e431-40b5-a896-e235eb3159f5","type":"BoxZoomTool"},{"attributes":{},"id":"1ba1576b-fdc5-4c48-8bfe-4a74195270bf","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"green"},"line_alpha":{"value":0.5},"line_color":{"value":"green"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a7e132c2-975a-437f-960e-1c9e023766b6","type":"Triangle"},{"attributes":{"callback":null,"column_names":["x","y","size"],"data":{"size":[12,18,24,30,36],"x":[1,2,3,4,5],"y":[1,9,4,8,2]}},"id":"7d2f2fac-28a5-4466-ac50-7bd5f70306c0","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"7f05c6b0-c541-4c58-ab22-55d8ee21c83b","subtype":"Figure","type":"Plot"},"ticker":{"id":"fd5d4f2a-1f15-4648-8459-e727bdb937ab","type":"BasicTicker"}},"id":"d6fdfbc5-2ada-47b7-9564-d5459f43c864","type":"Grid"},{"attributes":{},"id":"fd5d4f2a-1f15-4648-8459-e727bdb937ab","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Temperature Observations"},"id":"1ad714a0-96fb-434b-85e0-1b05aae199d8","type":"Title"},{"attributes":{},"id":"8bad238d-55d5-4bac-8fbb-ebfeff6da79c","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"2e758ac7-d544-4e6b-9cdd-d35559e86ab4","type":"BasicTickFormatter"},"plot":{"id":"7f05c6b0-c541-4c58-ab22-55d8ee21c83b","subtype":"Figure","type":"Plot"},"ticker":{"id":"21576e01-06f0-4495-aa98-838eaac608dd","type":"BasicTicker"}},"id":"6e5e896c-0171-4356-a0c2-a5c6fb64a223","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2ccf87ea-ce1d-4574-a2dd-d41271e023f6","type":"Circle"},{"attributes":{"data_source":{"id":"9e400864-ff9d-4b5e-94ae-4348c455e232","type":"ColumnDataSource"},"glyph":{"id":"0d6edbaa-785a-411f-a8fc-fdab82c6c88c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"2ccf87ea-ce1d-4574-a2dd-d41271e023f6","type":"Circle"},"selection_glyph":null},"id":"369efd7f-0ac0-4f3e-be27-ad504f9d0042","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"line_alpha":{"value":0.5},"line_color":{"value":"red"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d6edbaa-785a-411f-a8fc-fdab82c6c88c", ...

# %%
p = figure(plot_width=400, plot_height=400)
p.title.text = "Temperature Observations"
p.title.text_font = "times"
p.title.text_color = 'blue'
p.title.text_font_style = "italic"

p.xaxis.axis_label = "Day of Observation"
p.xaxis.minor_tick_line_color = None
p.yaxis.axis_label = "Temperature"

p.circle([1,2,3,4,5], [9,2,6,2,5], size=12, color='red', alpha=0.5)
p.line([1,2,3,4,5], [2,5,20,0.5,9], line_width=5, color='blue', alpha=0.5)

output_file("scatter_plotting.html", mode='inline')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c29690dd-beeb-4286-b295-698a1f52f9a9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#c29690dd-beeb-4286-b295-698a1f52f9a9").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c29690dd-beeb-4286-b295-698a1f52f9a9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c29690dd-beeb-4286-b295-698a1f52f9a9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"42c16cba-5255-46c4-97b8-5d761ccb0d81":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"blue"},"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":
type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"b3a878b6-ee17-4a22-901b-db56284c71f0","type":"Circle"},"selection_glyph":null},"id":"cb5cee55-751c-42e5-bd13-5662099b860d","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"26a0536c-84d1-44b1-a811-ac5b64d9a268","type":"LinearAxis"}],"left":[{"id":"c1ce7881-c1b5-4c12-b8e9-046bdb13759b","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"26a0536c-84d1-44b1-a811-ac5b64d9a268","type":"LinearAxis"},{"id":"0efe2cfe-5f95-48ae-bde8-7f5dda8e690d","type":"Grid"},{"id":"c1ce7881-c1b5-4c12-b8e9-046bdb13759b","type":"LinearAxis"},{"id":"5570977b-12c6-435b-8455-50ba6c04e29f","type":"Grid"},{"id":"3d0e1758-0f44-411f-9cc0-9299c403d2b2","type":"BoxAnnotation"},{"id":"cb5cee55-751c-42e5-bd13-5662099b860d","type":"GlyphRenderer"},{"id":"17173922-93ba-4b6e-9a49-5 ...

# %%
from bokeh.plotting import figure, output_notebook, show, gridplot
from numpy import *

x = arange(0, 2*pi, 0.1)

g1 = figure(width=400, height=400, title=None)
g1.line(x, sin(x), legend = 'sine of x')

g2 = figure(width=400, height=400, title=None)
g2.line(x, cos(x), legend = 'cosine of x')

gdp = gridplot([[g1, g2]])
#gdp = gridplot([[g1, g2], [g3, g4]])

output_notebook()
show(gdp)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a7ca6a0f-07cc-4d0a-afd6-b74af2259022">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="73ba5abd-fa9e-445d-b59d-de1a6adc5336"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#73ba5abd-fa9e-445d-b59d-de1a6adc5336").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("73ba5abd-fa9e-445d-b59d-de1a6adc5336");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '73ba5abd-fa9e-445d-b59d-de1a6adc5336' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"60291645-04e3-4cc8-aafb-8a18f0daa9d0":{"roots":{"references":[{"attributes":{},"id":"71e2163c-b3f4-4c67-b28e-ce3f3cdc80d4","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b8fdb54a-fde7-4c8a-83c5-d8cc3c01f6b6","type":"PanTool"},{"id":"d0121a5d-fbbd-4305-97ab-64c5003e5201","type":"WheelZoomTool"},{"id":"e5a2a400-18a4-4204-8f3b-3c9c9c25fc4e","type":"BoxZoomTool"},{"id":"25a1fdf3-3c7c-48ac-aeff-a169a48bdb95","type":"SaveTool"},{"id":"312effe9-3a74-4b74-8b0c-676c9fe36907","type":"ResetTool"},{"id":"d6f3a930-2243-4378-b92a-65798edda918","type":"HelpTool"}]},"id":"6dfdbc29-82fc-4c1e-841e-dc3ea69f6725","type":"Toolbar"},{"attributes":{"callback":null},"id":"fb7ee136-3bf0-4e59-a630-9291435a068c","type":"DataRange1d"},{"attributes":{},"id":"cb9d61da-cbdc-4ef2-9796-955a12a8c11f","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"7d1e802e-c3ec-4e8c-8464-e07d7fa2d064","type":"DataRange1d"},{"attributes":{"children":[{"id":"798010c9-c45d-4447-8f75-355b90c312a4","subtype":"Figure","type":"Plot"},{"id":"d04fc774-074f-4491-8e3b-fde705bfd7d1","subtype":"Figure","type":"Plot"}]},"id":"db108eac-f60f-4584-a547-86ce3e8ca067","type":"Row"},{"attributes":{},"id":"fe37c81a-22f5-4683-aae6-44c3a08f6cf7","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ecc6314a-b060-49b5-a554-0ed07cb73ca6","type":"Line"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"79660d80-654d-4a94-ac6b-b4fac48f883d","type":"PanTool"},{"id":"25ad0202-90d3-471e-8656-45c1221e7bc5","type":"WheelZoomTool"},{"id":"068e1bd5-707a-49a7-b255-d3bcc82fa8af","type":"BoxZoomTool"},{"id":"ee5c064d-9877-4463-9ccf-1130dfd7d8fb","type":"SaveTool"},{"id":"760d0a88-63b0-4770-9e64-4aac2c50aece","type":"ResetTool"},{"id":"66ebe3e8-0f68-44b7-9b11-7acb89c98155","type":"HelpTool"},{"id":"b8fdb54a-fde7-4c8a-83c5-d8cc3c01f6b6","type":"PanTool"},{"id":"d0121a5d-fbbd-4305-97ab-64c5003e5201","type":"WheelZoomTool"},{"id":"e5a2a400-18a4-4204-8f3b-3c9c9c25fc4e","type":"BoxZoomTool"},{"id":"25a1fdf3-3c7c-48ac-aeff-a169a48bdb95","type":"SaveTool"},{"id":"312effe9-3a74-4b74-8b0c-676c9fe36907","type":"ResetTool"},{"id":"d6f3a930-2243-4378-b92a-65798edda918","type":"HelpTool"}]},"id":"b5de3482-68f3-4e9e-98cb-1bdfc11d8589","type":"ToolbarBox"},{"attributes":{"formatter":{"id":"fb668419-234d-4f39-8f18-0f3f4dc16a5e","type":"BasicTickFormatter"},"plot":{"id":"d04fc774-074f-4491-8e3b-fde705bfd7d1","subtype":"Figure","type":"Plot"},"ticker":{"id":"a058804a-4371-4bf4-83cf-845cc6f1fcbe","type":"BasicTicker"}},"id":"21be56a5-7087-438a-b295-a8ac27a17621","type":"LinearAxis"},{"attributes":{},"id":"a058804a-4371-4bf4-83cf-845cc6f1fcbe","type":"BasicTicker"},{"attributes":{"below":[{"id":"27bb38d5-9b1e-450c-a52b-c50519e253c5","type":"LinearAxis"}],"left":[{"id":"21be56a5-7087-438a-b295-a8ac27a17621","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"27bb38d5-9b1e-450c-a52b-c50519e253c5","type":"LinearAxis"},{"id":"09c3728e-2104-49dc-a3cf-6fbc9f354fbc","type":"Grid"},{"id":"21be56a5-7087-438a-b295-a8ac27a17621","type":"LinearAxis"},{"id":"c0ae2e75-ec72-42cd-ac46-30f734c594ab","type":"Grid"},{"id":"fa622ac0-c889-4974-828e-0ec2cccf6f50","type":"BoxAnnotation"},{"id":"ff903e28-6025-4fa2-a509-2acde4b2d205","type":"Legend"},{"id":"6201a82a-20b8-47f2-9688-c02b11514235","type":"GlyphRenderer"}],"title":{"id":"5a030641-bfb8-437a-8b36-41685e6019e8","type":"Title"},"tool_events":{"id":"f2463fc2-654b-49a2-9675-b8e208949ab6","type":"ToolEvents"},"toolbar":{"id":"6dfdbc29-82fc-4c1e-841e-dc3ea69f6725","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"fb7ee136-3bf0-4e59-a630-9291435a068c","type":"DataRange1d"},"y_range":{"id":"4465642c-7d06-4ba0-a307-7e7283478ced","type":"DataRange1d"}},"id":"d04fc774-074f-4491-8e3b-fde705bfd7d1","subtype":"Figure","type":"Plot"},{ ...
