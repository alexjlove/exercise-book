# %%
import sklearn.linear_model

# %%
import pandas
import matplotlib.pyplot

# %%
# %matplotlib inline

# %%
df = pandas.DataFrame(
    {'jam_rating' : [2,4,7,8,9],
     'jam_price' : [1,2,3,4,5]
    }
)
df
# Out:
#    jam_price  jam_rating
# 0          1           2
# 1          2           4
# 2          3           7
# 3          4           8
# 4          5           9

# %%
df.plot.scatter('jam_price', 'jam_rating')

# %%
import seaborn
seaborn.pairplot(data=df)

# %%
ransac = sklearn.linear_model.RANSACRegressor()

# %%
ransac.fit(df[['jam_price']], df.jam_rating)
# Out:
# RANSACRegressor(base_estimator=None, is_data_valid=None, is_model_valid=None,
#         max_trials=100, min_samples=None, random_state=None,
#         residual_metric=None, residual_threshold=None, stop_n_inliers=inf,
#         stop_probability=0.99, stop_score=inf)

# %%
ransac.estimator_
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
ransac.estimator_.coef_
# Out:
# array([ 1.8])

# %%
ransac.estimator_.intercept_
# Out:
# 0.60000000000000053

# %%
ransac.predict([2.5])
# Out:
# /home/useraj/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([ 5.1])

# %%
ransac.predict([[2.5],[3.5],[4.5]])
# Out:
# array([ 5.1,  6.9,  8.7])

# %%
predictions = ransac.predict( df[["jam_price"]] )
predictions
# Out:
# array([ 2.4,  4.2,  6. ,  7.8,  9.6])

# %%
matplotlib.pyplot.scatter(df.jam_price, df.jam_rating)
matplotlib.pyplot.scatter(df.jam_price, predictions, color='red')

# %%
theilsen = sklearn.linear_model.TheilSenRegressor()
theilsen.fit(df[["jam_price"]], df.jam_rating)
theilsen_predictions = theilsen.predict(df[["jam_price"]])
matplotlib.pyplot.scatter(df.jam_price, df.jam_rating)
matplotlib.pyplot.scatter(df.jam_price, theilsen_predictions, color='red')
zip(df.jam_price, theilsen_predictions)
# Out:
# [(1, 2.034727287982228),
#  (2, 4.0204735951594195),
#  (3, 6.0062199023366114),
#  (4, 7.9919662095138033),
#  (5, 9.9777125166909943)]

# %%
theilsen.coef_
# Out:
# array([ 1.98574631])

# %%
theilsen.intercept_
# Out:
# 0.048980980805036024

# %%
l = sklearn.linear_model.LinearRegression()
l.fit(df[["jam_price"]], df.jam_rating)
l_predictions = l.predict(df[["jam_price"]])
matplotlib.pyplot.scatter(df.jam_price, df.jam_rating)
matplotlib.pyplot.scatter(df.jam_price, l_predictions, color='red')
zip(df.jam_price, l_predictions)
# Out:
# [(1, 2.4000000000000004),
#  (2, 4.2000000000000002),
#  (3, 6.0),
#  (4, 7.7999999999999998),
#  (5, 9.6000000000000014)]

# %% [markdown]
# # Multi-dimensional linear regression

# %%
sacramento = pandas.read_csv('CSV/Sacramentorealestatetransactions.csv',
                             index_col=0
                            )
sacramento
# Out:
#                                             city    zip state  beds  baths  \
# street
# 3526 HIGH ST                          SACRAMENTO  95838    CA     2      1
# 51 OMAHA CT                           SACRAMENTO  95823    CA     3      1
# 2796 BRANCH ST                        SACRAMENTO  95815    CA     2      1
# 2805 JANETTE WAY                      SACRAMENTO  95815    CA     2      1
# 6001 MCMAHON DR                       SACRAMENTO  95824    CA     2      1
# 5828 PEPPERMILL CT                    SACRAMENTO  95841    CA     3      1
# 6048 OGDEN NASH WAY                   SACRAMENTO  95842    CA     3      2
# 2561 19TH AVE                         SACRAMENTO  95820    CA     3      1
# 11150 TRINITY RIVER DR Unit 114   RANCHO CORDOVA  95670    CA     2      2
# 7325 10TH ST                           RIO LINDA  95673    CA     3      2
# 645 MORRISON AVE                      SACRAMENTO  95838    CA     3      2
# 4085 FAWN CIR                         SACRAMENTO  95823    CA     3      2
# 2930 LA ROSA RD                       SACRAMENTO  95815    CA     1      1
# 2113 KIRK WAY                         SACRAMENTO  95822    CA     3      1
# 4533 LOCH HAVEN WAY                   SACRAMENTO  95842    CA     2      2
# 7340 HAMDEN PL                        SACRAMENTO  95842    CA     2      2
# 6715 6TH ST                            RIO LINDA  95673    CA     2      1
# 6236 LONGFORD DR Unit 1           CITRUS HEIGHTS  95621    CA     2      1
# 250 PERALTA AVE                       SACRAMENTO  95833    CA     2      1
# 113 LEEWILL AVE                        RIO LINDA  95673    CA     3      2
# 6118 STONEHAND AVE                CITRUS HEIGHTS  95621    CA     3      2
# 4882 BANDALIN WAY                     SACRAMENTO  95823    CA     4      2
# 7511 OAKVALE CT                  NORTH HIGHLANDS  95660    CA     4      2
# 9 PASTURE CT                          SACRAMENTO  95834    CA     3      2
# 3729 BAINBRIDGE DR               NORTH HIGHLANDS  95660    CA     3      2
# 3828 BLACKFOOT WAY                      ANTELOPE  95843    CA     3      2
# 4108 NORTON WAY                       SACRAMENTO  95820    CA     3      1
# 1469 JANRICK AVE                      SACRAMENTO  95832    CA     3      2
# 9861 CULP WAY                         SACRAMENTO  95827    CA     4      2
# 7825 CREEK VALLEY CIR                 SACRAMENTO  95828    CA     3      2
# ...                                          ...    ...   ...   ...    ...
# 2100 BEATTY WAY                        ROSEVILLE  95747    CA     3      2
# 6920 GILLINGHAM WAY              NORTH HIGHLANDS  95660    CA     3      1
# 82 WILDFLOWER DR                            GALT  95632    CA     3      2
# 8652 BANTON CIR                        ELK GROVE  95624    CA     4      2
# 8428 MISTY PASS WAY                     ANTELOPE  95843    CA     3      2
# 7958 ROSEVIEW WAY                     SACRAMENTO  95828    CA     3      2
# 9020 LUKEN CT                          ELK GROVE  95624    CA     3      2
# 7809 VALLECITOS WAY                   SACRAMENTO  95828    CA     3      1
# 8445 OLD AUBURN RD                CITRUS HEIGHTS  95610    CA     3      2
# 10085 ATKINS DR                        ELK GROVE  95757    CA     3      2
# 9185 CERROLINDA CIR                    ELK GROVE  95758    CA     3      2
# 9197 CORTINA CIR                       ROSEVILLE  95678    CA     3      2
# 5429 HESPER WAY                       CARMICHAEL  95608    CA     4      2
# 1178 WARMWOOD CT                            GALT  95632    CA     4      2
# 4900 ELUDE CT                         SACRAMENTO  95842    CA     4      2
# 3557 SODA WAY                         SACRAMENTO  95834    CA     0      0
# 645 MORRISON AVE                 38.637663 -121.451520
# 4085 FAWN CIR                    38.470746 -121.458918
# 2930 LA ROSA RD                  38.618698 -121.435833
# 2113 KIRK WAY                    38.482215 -121.492603
# 4533 LOCH HAVEN WAY              38.672914 -121.359340
# 7340 HAMDEN PL                   38.700051 -121.351278
# 6715 6TH ST                      38.689591 -121.452239
# 6236 LONGFORD DR Unit 1          38.679776 -121.314089
# 250 PERALTA AVE                  38.612099 -121.469095
# 113 LEEWILL AVE                  38.689999 -121.463220
# 6118 STONEHAND AVE               38.707851 -121.320707
# 4882 BANDALIN WAY                38.468173 -121.444071
# 7511 OAKVALE CT                  38.702792 -121.382210
# 9 PASTURE CT                     38.628631 -121.488097
# 3729 BAINBRIDGE DR               38.701499 -121.376220
# 3828 BLACKFOOT WAY               38.709740 -121.373770
# 4108 NORTON WAY                  38.537526 -121.478315
# 1469 JANRICK AVE                 38.476472 -121.501711
# 9861 CULP WAY                    38.558423 -121.327948
# 7825 CREEK VALLEY CIR            38.472122 -121.404199
# ...                                    ...         ...
# 2100 BEATTY WAY                  38.737882 -121.308142
# 6920 GILLINGHAM WAY              38.694279 -121.373395
# 82 WILDFLOWER DR                 38.259708 -121.311616
# 8652 BANTON CIR                  38.444000 -121.370993
# 8428 MISTY PASS WAY              38.722959 -121.347115
# 7958 ROSEVIEW WAY                38.467836 -121.410366
# 9020 LUKEN CT                    38.451398 -121.366614
# 7809 VALLECITOS WAY              38.508217 -121.411207
# 8445 OLD AUBURN RD               38.715423 -121.246743
# 10085 ATKINS DR                  38.390893 -121.437821
# 9185 CERROLINDA CIR              38.424497 -121.426595
# 9197 CORTINA CIR                 38.793152 -121.290025
# 5429 HESPER WAY                  38.665104 -121.315901
# 1178 WARMWOOD CT                 38.289544 -121.284607
# 4900 ELUDE CT                    38.696740 -121.350519
# 3557 SODA WAY                    38.631026 -121.501879
# 3528 SAINT GEORGE DR             38.629468 -121.376445
# 7381 WASHBURN WAY                38.703550 -121.375103
# 2181 WINTERHAVEN CIR             38.697570 -120.995739
# 7540 HICKORY AVE                 38.703056 -121.235221
# 5024 CHAMBERLIN CIR              38.389756 -121.446246
# 2400 INVERNESS DR                38.897814 -121.324691
# 5 BISHOPGATE CT                  38.467936 -121.445477
# 5601 REXLEIGH DR                 38.445342 -121.441504
# 1909 YARNELL WAY                 38.417382 -121.484325
# 9169 GARLINGTON CT               38.457679 -121.359620
# 6932 RUSKUT WAY                  38.499893 -121.458890
# 7933 DAFFODIL WAY                38.708824 -121.256803
# 8304 RED FOX WAY                 38.417000 -121.397424
# 3882 YELLOWSTONE LN              38.655245 -121.075915
#
# [985 rows x 11 columns]

# %%
sacramento.columns
# Out:
# Index([u'city', u'zip', u'state', u'beds', u'baths', u'sq__ft', u'type',
#        u'sale_date', u'price', u'latitude', u'longitude'],
#       dtype='object')

# %%
x = sacramento[['beds', 'baths', 'sq__ft', 'latitude', 'longitude']]
y = sacramento.price

# %%
seaborn.pairplot(sacramento)

# %%
ols = sklearn.linear_model.LinearRegression()
ols.fit(x,y)
zip(['beds', 'baths', 'sq__ft', 'latitude', 'longitude'], ols.coef_)
# Out:
# [('beds', -5177.0604470771859),
#  ('baths', 47018.31751263779),
#  ('sq__ft', 34.440179386991076),
#  ('latitude', -25449.698100080914),
#  ('longitude', 325120.7717371895)]

# %%
ols.score(x, y)
# Out:
# 0.27428458034206371

# %%
t2 = sklearn.linear_model.TheilSenRegressor()
t2.fit(x,y)
zip(['beds', 'baths', 'sq__ft', 'latitude', 'longitude'], t2.coef_)
# Out:
# [('beds', 56468.466749656502),
#  ('baths', 210799.66675767038),
#  ('sq__ft', 112.88974597871172),
#  ('latitude', -40859.970150453155),
#  ('longitude', 204468.33842478713)]

# %%
t2.score(x,y)
# Out:
# -3.938054058795188

# %%
r2 = sklearn.linear_model.RANSACRegressor()
r2.fit(x,y)
zip(['beds', 'baths', 'sq__ft', 'latitude', 'longitude'], r2.estimator_.coef_)
# Out:
# [('beds', -5516.2641988149962),
#  ('baths', -3569.9194126467851),
#  ('sq__ft', 136.41405641858773),
#  ('latitude', 30467.467512371164),
#  ('longitude', -8930.5997179483529)]

# %%
lasso = sklearn.linear_model.Lasso(alpha=10000)
lasso.fit(x,y)
zip(['beds', 'baths', 'sq__ft', 'latitude', 'longitude'], lasso.coef_)
# Out:
# [('beds', 0.0),
#  ('baths', 31413.877120481931),
#  ('sq__ft', 32.195447112137231),
#  ('latitude', 0.0),
#  ('longitude', 0.0)]

# %%
lasso.score(x,y)
# Out:
# 0.16732308502626614

# %%
lasso_prediction = lasso.predict(x)
matplotlib.pyplot.scatter(sacramento.baths, sacramento.price)
matplotlib.pyplot.scatter(sacramento.baths, lasso_prediction, color='red')

# %% [markdown]
# # How could we improve?
#
# Let's do some non-linear stuff

# %%
matplotlib.pyplot.scatter(sacramento.latitude, sacramento.price)

# %%
(sacramento.latitude < 38.35).value_counts()
# Out:
# False    962
# True      23
# Name: latitude, dtype: int64

# %%
(sacramento.latitude < 38.3).value_counts()
# Out:
# False    963
# True      22
# Name: latitude, dtype: int64

# %%
import numpy
sacramento['river_south'] = numpy.where(sacramento.latitude < 38.35, 1, 0)

# %%
X = sacramento[['beds', 'baths', 'sq__ft', 'latitude', 'longitude', 'river_south']]

# %%
ols.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
zip(['beds', 'baths', 'sq__ft', 'latitude', 'longitude', 'river_south'], ols.coef_)
# Out:
# [('beds', -5210.2467788956574),
#  ('baths', 46814.697557668442),
#  ('sq__ft', 34.031674132944318),
#  ('latitude', -40180.517431029119),
#  ('longitude', 332190.09876962402),
#  ('river_south', -29114.578355446534)]

# %%
ols.score(X,y)
# Out:
# 0.27511225117176896

# %%
matplotlib.pyplot.cm.Reds

# %%
import matplotlib.colors
normify = matplotlib.colors.Normalize(sacramento.price.min(), 
                                      sacramento.price.max())
price_coloured = matplotlib.pyplot.cm.RdBu_r(normify(sacramento.price))

# %%
matplotlib.pyplot.scatter(sacramento.longitude, sacramento.latitude,
                          color=price_coloured
                          )

# %%
sacramento.price.median()
# Out:
# 213750.0

# %%
sacramento.price.mean()
# Out:
# 234144.26395939087

# %%
expensive_houses = sacramento[sacramento.price > 250000]
cheap_houses = sacramento[sacramento.price <= 250000]
matplotlib.pyplot.scatter(expensive_houses.longitude,
                          expensive_houses.latitude,
                          color='red')
matplotlib.pyplot.scatter(cheap_houses.longitude,
                          cheap_houses.latitude,
                          color='blue')

# %% [markdown]
# Let's add another variable for "North Eastern"-ness

# %%
northeastern = (sacramento.latitude > 38.6) & (sacramento.longitude > -121.4)

# %%
sacramento['northeast'] = numpy.where(northeastern, 1, 0)

# %%
data_columns = ['beds', 
                'baths',
                'sq__ft', 
                'latitude', 
                'longitude', 
                'river_south',
                'northeast']
X = sacramento[data_columns]
ols.fit(X,y)
zip(data_columns, ols.coef_)
# Out:
# [('beds', -5387.6493670618629),
#  ('baths', 46560.479038643636),
#  ('sq__ft', 34.042869619668636),
#  ('latitude', -71534.27195492966),
#  ('longitude', 313241.88002935232),
#  ('river_south', -33217.420296075645),
#  ('northeast', 14250.777006510045)]

# %%
ols.score(X,y)
# Out:
# 0.27585252764779855

# %%
sacramento['postcode_region'] = sacramento.zip.map(lambda x: int(x / 10))
sacramento.postcode_region.nunique()
# Out:
# 19

# %%
matplotlib.pyplot.scatter(sacramento.postcode_region, sacramento.price)

# %%
p9575 = sacramento[sacramento.postcode_region == 9575]
p9576 = sacramento[sacramento.postcode_region == 9576]
p9575.price.mean()
# Out:
# 279833.65

# %%
p9576.price.mean()
# Out:
# 447542.35294117645

# %%
import scipy.stats
scipy.stats.mannwhitneyu(p9575.price, p9576.price)
# Out:
# MannwhitneyuResult(statistic=433.5, pvalue=4.8577455165135305e-09)

# %%
for pcode in sacramento.postcode_region.unique():
    for qcode in sacramento.postcode_region.unique():
        if pcode > qcode: continue
        p1 = sacramento[sacramento.postcode_region == pcode]
        p2 = sacramento[sacramento.postcode_region == qcode]
        print pcode, qcode, scipy.stats.mannwhitneyu(p1.price, p2.price),
# Out:
# 9583 9583 MannwhitneyuResult(statistic=9522.0, pvalue=0.4996991360527468)
# 9583 9584 MannwhitneyuResult(statistic=3654.0, pvalue=0.049776458531163394)
# 9583 9586 MannwhitneyuResult(statistic=226.0, pvalue=0.09640638632338383)
# 9582 9583 MannwhitneyuResult(statistic=10942.0, pvalue=2.5845239066376338e-06)
# 9582 9582 MannwhitneyuResult(statistic=24642.0, pvalue=0.49985244243107652)
# 9582 9584 MannwhitneyuResult(statistic=5703.5, pvalue=0.019679535382575129)
# 9582 9586 MannwhitneyuResult(statistic=277.0, pvalue=0.028007049139626868)
# 9581 9583 MannwhitneyuResult(statistic=2853.0, pvalue=0.20752317960220229)
# 9581 9582 MannwhitneyuResult(statistic=4674.0, pvalue=0.24871127457361508)
# 9581 9581 MannwhitneyuResult(statistic=1012.5, pvalue=0.49838992774762603)
# 9581 9584 MannwhitneyuResult(statistic=1388.0, pvalue=0.48363986836071343)
# 9581 9586 MannwhitneyuResult(statistic=71.0, pvalue=0.092432255973977417)
# 9584 9584 MannwhitneyuResult(statistic=1922.0, pvalue=0.4990030545680581)
# 9584 9586 MannwhitneyuResult(statistic=89.5, pvalue=0.060465587164021228)
# 9567 9583 MannwhitneyuResult(statistic=3541.5, pvalue=0.053282746714505398)
# 9567 9582 MannwhitneyuResult(statistic=4001.5, pvalue=1.0551987824268674e-06)
# 9567 9581 MannwhitneyuResult(statistic=1113.5, pvalue=0.063230953846741447)
# 9567 9584 MannwhitneyuResult(statistic=1347.5, pvalue=0.0043695274403034601)
# 9567 9567 MannwhitneyuResult(statistic=1800.0, pvalue=0.49895285286195318)
# 9567 9575 MannwhitneyuResult(statistic=1978.5, pvalue=0.0381328899732978)
# 9567 9574 MannwhitneyuResult(statistic=451.0, pvalue=3.8434251605452124e-06)
# 9567 9572 MannwhitneyuResult(statistic=114.5, pvalue=0.44484907670253854)
# 9567 9576 MannwhitneyuResult(statistic=277.0, pvalue=2.5645480161348721e-09)
# 9567 9568 MannwhitneyuResult(statistic=406.0, pvalue=0.42609402682978292)
# 9567 9569 MannwhitneyuResult(statistic=145.5, pvalue=0.013569910746818613)
# 9567 9586 MannwhitneyuResult(statistic=111.5, pvalue=0.17474811378932881)
# 9562 9583 MannwhitneyuResult(statistic=5304.0, pvalue=0.49224668012797901)
# 9562 9582 MannwhitneyuResult(statistic=5694.5, pvalue=6.4195492642412918e-06)
# 9562 9581 MannwhitneyuResult(statistic=1560.5, pvalue=0.18140023568847302)
# 9562 9584 MannwhitneyuResult(statistic=2028.5, pvalue=0.064635772649877535)
# 9562 9567 MannwhitneyuResult(statistic=1940.5, pvalue=0.054698352839267092)
# 9562 9562 MannwhitneyuResult(statistic=2964.5, pvalue=0.49927912272455233)
# 9562 9566 MannwhitneyuResult(statistic=1901.0, pvalue=0.3814156214825779)
# 9562 9575 MannwhitneyuResult(statistic=1950.0, pvalue=3.6517305836838002e-05)
# 9562 9563 MannwhitneyuResult(statistic=922.0, pvalue=0.00010459565319102213)
# 9562 9565 MannwhitneyuResult(statistic=35.0, pvalue=0.021379885988292869)
# 9562 9574 MannwhitneyuResult(statistic=388.5, pvalue=1.9820452675188672e-09)
# 9562 9572 MannwhitneyuResult(statistic=116.5, pvalue=0.2099637600879759)
# 9562 9576 MannwhitneyuResult(statistic=191.0, pvalue=4.3641418820033763e-13)
# 9562 9568 MannwhitneyuResult(statistic=461.0, pvalue=0.19696182019015784)
# 9562 9569 MannwhitneyuResult(statistic=178.0, pvalue=0.0088888378888533175)
# 9562 9586 MannwhitneyuResult(statistic=123.0, pvalue=0.090583464249921586)
# 9562 9564 MannwhitneyuResult(statistic=1309.0, pvalue=7.6972764884547819e-09)
# 9566 9583 MannwhitneyuResult(statistic=3276.5, pvalue=0.23423810320711003)
# 9566 9582 MannwhitneyuResult(statistic=3992.0, pvalue=0.00051598843382916041)
# 9566 9581 MannwhitneyuResult(statistic=944.5, pvalue=0.068534875061565165)
# 9566 9584 MannwhitneyuResult(statistic=1298.0, pvalue=0.051551523523187731)
# 9566 9567 MannwhitneyuResult(statistic=1452.5, pvalue=0.32432074398337774)
# 9566 9566 MannwhitneyuResult(statistic=1300.5, pvalue=0.49866471736104634)
# 9566 9575 MannwhitneyuResult(statistic=1571.0, pvalue=0.013498932629199415)
# 9566 9574 MannwhitneyuResult(statistic=411.0, pvalue=2.1928149061593608e-05)
# 9566 9572 MannwhitneyuResult(statistic=89.0, pvalue=0.3426839027749724)
# 9566 9576 MannwhitneyuResult(statistic=279.5, pvalue=6.9745467252360106e-08)
# 9566 9568 MannwhitneyuResult(statistic=335.5, pvalue=0.36876372540707814)
# 9566 9569 MannwhitneyuResult(statistic=118.0, pvalue=0.010779325828706499)
# 9566 9586 MannwhitneyuResult(statistic=95.5, pvalue=0.18269142299612123)
# 9575 9583 MannwhitneyuResult(statistic=3632.5, pvalue=1.3111163405965142e-05)
# 9575 9582 MannwhitneyuResult(statistic=3360.0, pvalue=8.4332650419836061e-17)
# 9575 9581 MannwhitneyuResult(statistic=1287.0, pvalue=0.0041930930802361955)
# 9575 9584 MannwhitneyuResult(statistic=1269.0, pvalue=3.1935516678353963e-07)
# 9575 9575 MannwhitneyuResult(statistic=3200.0, pvalue=0.49931920968545906)
# 9575 9576 MannwhitneyuResult(statistic=433.5, pvalue=4.8577455165135305e-09)
# 9575 9586 MannwhitneyuResult(statistic=170.0, pvalue=0.29081736168110228)
# 9563 9583 MannwhitneyuResult(statistic=1665.0, pvalue=3.2500729459545858e-05)
# 9563 9582 MannwhitneyuResult(statistic=1670.5, pvalue=6.1274156252599072e-11)
# 9563 9581 MannwhitneyuResult(statistic=570.0, pvalue=0.0011687676698183735)
# 9563 9584 MannwhitneyuResult(statistic=612.0, pvalue=4.5700545256556795e-06)
# 9563 9567 MannwhitneyuResult(statistic=889.5, pvalue=0.0093527423214343208)
# 9563 9566 MannwhitneyuResult(statistic=734.5, pvalue=0.0073607081438050335)
# 9563 9575 MannwhitneyuResult(statistic=1427.5, pvalue=0.12282762260210967)
# 9563 9563 MannwhitneyuResult(statistic=840.5, pvalue=0.49814969572460666)
# 9563 9565 MannwhitneyuResult(statistic=48.0, pvalue=0.27248776260064078)
# 9563 9574 MannwhitneyuResult(statistic=524.0, pvalue=0.033186631755168623)
# 9563 9572 MannwhitneyuResult(statistic=56.0, pvalue=0.15457169578156726)
# 9563 9576 MannwhitneyuResult(statistic=369.5, pvalue=0.00025041098610415423)
# 9563 9568 MannwhitneyuResult(statistic=225.5, pvalue=0.11926808079898371)
# 9563 9569 MannwhitneyuResult(statistic=136.0, pvalue=0.11273964872395803)
# 9563 9586 MannwhitneyuResult(statistic=94.0, pvalue=0.38884580970148419)
# 9563 9564 MannwhitneyuResult(statistic=436.0, pvalue=4.6795423744853094e-11)
# 9560 9583 MannwhitneyuResult(statistic=1040.5, pvalue=0.00081609856423005527)
# 9560 9582 MannwhitneyuResult(statistic=915.5, pvalue=2.0182235823760436e-08)
# 9560 9581 MannwhitneyuResult(statistic=359.0, pvalue=0.0064176378046619156)
# 9560 9584 MannwhitneyuResult(statistic=354.5, pvalue=4.0829567461686864e-05)
# 9560 9567 MannwhitneyuResult(statistic=564.5, pvalue=0.03717838911941334)
# 9560 9562 MannwhitneyuResult(statistic=570.0, pvalue=0.0011452100413360709)
# 9560 9566 MannwhitneyuResult(statistic=443.5, pvalue=0.01620284154388307)
# 9560 9575 MannwhitneyuResult(statistic=918.5, pvalue=0.27111518540135926)
# 9560 9563 MannwhitneyuResult(statistic=505.0, pvalue=0.4631359873643015)
# 9560 9560 MannwhitneyuResult(statistic=312.5, pvalue=0.49612668208091409)
# 9560 9565 MannwhitneyuResult(statistic=25.0, pvalue=0.18634132377634738)
# 9560 9574 MannwhitneyuResult(statistic=282.5, pvalue=0.014691561302447314)
# 9560 9572 MannwhitneyuResult(statistic=36.0, pvalue=0.19657462053952329)
# 9560 9576 MannwhitneyuResult(statistic=209.0, pvalue=0.00047358912607869128)
# 9560 9568 MannwhitneyuResult(statistic=140.5, pvalue=0.15972974447242205)
# 9560 9569 MannwhitneyuResult(statistic=88.5, pvalue=0.17944394467356961)
# 9560 9586 MannwhitneyuResult(statistic=56.0, pvalue=0.36921651073007683)
# 9560 9564 MannwhitneyuResult(statistic=299.5, pvalue=5.7211878782099061e-08)
# 9560 9561 MannwhitneyuResult(statistic=78.0, pvalue=0.092200515538206185)
# 9565 9583 MannwhitneyuResult(statistic=80.5, pvalue=0.03591262501191976)
# 9565 9582 MannwhitneyuResult(statistic=58.0, pvalue=0.0071209874632525176)
# 9565 9581 MannwhitneyuResult(statistic=33.0, pvalue=0.073780727249974712)
# 9565 9584 MannwhitneyuResult(statistic=25.0, pvalue=0.017410719707183255)
# 9565 9567 MannwhitneyuResult(statistic=51.0, pvalue=0.1069944296617884)
# 9565 9566 MannwhitneyuResult(statistic=38.0, pvalue=0.07563409055899066)
# 9565 9575 MannwhitneyuResult(statistic=78.0, pvalue=0.15564024459661402)
# 9565 9565 MannwhitneyuResult(statistic=4.5, pvalue=0.40973848838876059)
# 9565 9574 MannwhitneyuResult(statistic=47.0, pvalue=0.42278717053498016)
# 9565 9572 MannwhitneyuResult(statistic=2.0, pvalue=0.10796246947007015)
# 9565 9576 MannwhitneyuResult(statistic=39.0, pvalue=0.26110158404232742)
# 9565 9568 MannwhitneyuResult(statistic=11.0, pvalue=0.11553218948121624)
# 9565 9569 MannwhitneyuResult(statistic=13.0, pvalue=0.5)
# 9565 9586 MannwhitneyuResult(statistic=6.0, pvalue=0.38279724199788201)
# 9574 9583 MannwhitneyuResult(statistic=754.0, pvalue=4.6992071968620135e-10)
# 9574 9582 MannwhitneyuResult(statistic=613.5, pvalue=1.9235819445240266e-15)
# 9574 9581 MannwhitneyuResult(statistic=354.5, pvalue=2.4564908630828402e-05)
# 9574 9584 MannwhitneyuResult(statistic=241.0, pvalue=2.4154412374076134e-10)
# 9574 9575 MannwhitneyuResult(statistic=751.0, pvalue=8.1937517401906081e-05)
# 9574 9574 MannwhitneyuResult(statistic=578.0, pvalue=0.49755222311089276)
# 9574 9576 MannwhitneyuResult(statistic=433.0, pvalue=0.03815654990665459)
# 9574 9586 MannwhitneyuResult(statistic=75.0, pvalue=0.3449023110449897)
# 9572 9583 MannwhitneyuResult(statistic=221.0, pvalue=0.25079662271605441)
# 9572 9582 MannwhitneyuResult(statistic=188.0, pvalue=0.024337224296268809)
# 9572 9581 MannwhitneyuResult(statistic=75.0, pvalue=0.29823204271905318)
# 9572 9584 MannwhitneyuResult(statistic=73.5, pvalue=0.089520639627130028)
# 9572 9575 MannwhitneyuResult(statistic=126.0, pvalue=0.24081606162482416)
# 9572 9574 MannwhitneyuResult(statistic=20.0, pvalue=0.011923296698372486)
# 9572 9572 MannwhitneyuResult(statistic=8.0, pvalue=0.44121005703775179)
# 9572 9576 MannwhitneyuResult(statistic=8.0, pvalue=0.0023242296587675723)
# 9572 9586 MannwhitneyuResult(statistic=7.0, pvalue=0.27014568730370997)
# 9576 9583 MannwhitneyuResult(statistic=361.0, pvalue=1.1703693085695999e-14)
# 9576 9582 MannwhitneyuResult(statistic=239.5, pvalue=7.478838409845498e-19)
# 9576 9581 MannwhitneyuResult(statistic=239.0, pvalue=9.7812776390183793e-08)
# 9576 9584 MannwhitneyuResult(statistic=98.0, pvalue=1.2397231106287625e-13)
# 9576 9576 MannwhitneyuResult(statistic=578.0, pvalue=0.49755222311089276)
# 9576 9586 MannwhitneyuResult(statistic=65.5, pvalue=0.21235376315897131)
# 9568 9583 MannwhitneyuResult(statistic=812.5, pvalue=0.16481517179729266)
# 9568 9582 MannwhitneyuResult(statistic=949.0, pvalue=0.0073435665176287933)
# 9568 9581 MannwhitneyuResult(statistic=259.5, pvalue=0.16352871224012266)
# 9568 9584 MannwhitneyuResult(statistic=309.5, pvalue=0.048300529868792366)
# 9568 9575 MannwhitneyuResult(statistic=494.0, pvalue=0.24332553221818254)
# 9568 9574 MannwhitneyuResult(statistic=136.0, pvalue=0.010649578334481356)
# 9568 9572 MannwhitneyuResult(statistic=28.0, pvalue=0.47881542133105265)
# 9568 9576 MannwhitneyuResult(statistic=80.0, pvalue=0.00017661267527486175)
# 9568 9568 MannwhitneyuResult(statistic=98.0, pvalue=0.4908078611295083)
# 9568 9569 MannwhitneyuResult(statistic=40.0, pvalue=0.078136696034047728)
# 9568 9586 MannwhitneyuResult(statistic=26.0, pvalue=0.21555534000330312)
# 9569 9583 MannwhitneyuResult(statistic=296.0, pvalue=0.004371608997328703)
# 9569 9582 MannwhitneyuResult(statistic=329.0, pvalue=0.00032891324552160968)
# 9569 9581 MannwhitneyuResult(statistic=95.5, pvalue=0.0067171479093230714)
# 9569 9584 MannwhitneyuResult(statistic=121.5, pvalue=0.0033298088159505277)
# 9569 9575 MannwhitneyuResult(statistic=243.5, pvalue=0.057211561878298477)
# 9569 9574 MannwhitneyuResult(statistic=142.0, pvalue=0.37695366753608717)
# 9569 9572 MannwhitneyuResult(statistic=11.0, pvalue=0.15793723991524478)
# 9569 9576 MannwhitneyuResult(statistic=146.0, pvalue=0.4230620548942513)
# 9569 9569 MannwhitneyuResult(statistic=40.5, pvalue=0.4823096976815231)
# 9569 9586 MannwhitneyuResult(statistic=18.0, pvalue=0.29690142860385121)
# 9586 9586 MannwhitneyuResult(statistic=12.5, pvalue=0.45776498668838594)
# 9564 9583 MannwhitneyuResult(statistic=2265.0, pvalue=3.8305123906401416e-11)
# 9564 9582 MannwhitneyuResult(statistic=4222.5, pvalue=8.3672055005932596e-10)
# 9564 9581 MannwhitneyuResult(statistic=673.5, pvalue=1.8358216602860481e-08)
# 9564 9584 MannwhitneyuResult(statistic=1111.5, pvalue=1.4904280132462584e-07)
# 9564 9567 MannwhitneyuResult(statistic=879.5, pvalue=9.5455653893801358e-10)
# 9564 9566 MannwhitneyuResult(statistic=750.5, pvalue=4.3338682116472757e-09)
# 9564 9575 MannwhitneyuResult(statistic=1041.5, pvalue=2.620441795889344e-12)
# 9564 9565 MannwhitneyuResult(statistic=30.0, pvalue=0.0068052290488683264)
# 9564 9574 MannwhitneyuResult(statistic=249.5, pvalue=1.9005773189343638e-12)
# 9564 9572 MannwhitneyuResult(statistic=65.0, pvalue=0.0164101827119018)
# 9564 9576 MannwhitneyuResult(statistic=153.5, pvalue=1.1837834924671309e-14)
# 9564 9568 MannwhitneyuResult(statistic=239.0, pvalue=0.00030500521589352231)
# 9564 9569 MannwhitneyuResult(statistic=71.0, pvalue=8.5351575351636559e-06)
# 9564 9586 MannwhitneyuResult(statistic=48.5, pvalue=0.00083574587983678528)
# 9564 9564 MannwhitneyuResult(statistic=2592.0, pvalue=0.49903686512327905)
# 9561 9583 MannwhitneyuResult(statistic=534.0, pvalue=0.24230270828895073)
# 9561 9582 MannwhitneyuResult(statistic=465.0, pvalue=0.0033179663292307493)
# 9561 9581 MannwhitneyuResult(statistic=170.5, pvalue=0.23233828357994485)
# 9561 9584 MannwhitneyuResult(statistic=184.5, pvalue=0.052125518883773453)
# 9561 9567 MannwhitneyuResult(statistic=257.5, pvalue=0.41533810431142282)
# 9561 9562 MannwhitneyuResult(statistic=275.5, pvalue=0.15995120046549016)
# 9561 9566 MannwhitneyuResult(statistic=205.5, pvalue=0.31329023910900844)
# 9561 9575 MannwhitneyuResult(statistic=258.5, pvalue=0.084645029519384907)
# 9561 9563 MannwhitneyuResult(statistic=119.5, pvalue=0.051679773780791936)
# 9561 9565 MannwhitneyuResult(statistic=5.0, pvalue=0.069543364880006814)
# 9561 9574 MannwhitneyuResult(statistic=43.0, pvalue=0.00053913115529533148)
# 9561 9572 MannwhitneyuResult(statistic=16.0, pvalue=0.40848066085769563)
# 9561 9576 MannwhitneyuResult(statistic=13.0, pvalue=1.5570528961386081e-05)
# 9561 9568 MannwhitneyuResult(statistic=61.0, pvalue=0.46233167518942048)
# 9561 9569 MannwhitneyuResult(statistic=24.0, pvalue=0.078852193731538844)
# 9561 9586 MannwhitneyuResult(statistic=16.0, pvalue=0.21185539858339669)
# 9561 9564 MannwhitneyuResult(statistic=151.0, pvalue=0.0016532416589846721)
# 9561 9561 MannwhitneyuResult(statistic=40.5, pvalue=0.4823096976815231)

# %%
unusual_post_code_regions = [9582, 9583, 9567, 9574, 9562, 9566, 9576]
for code in unusual_post_code_regions:
    column_name = "p" + str(code)
    sacramento[column_name] = numpy.where(sacramento.postcode_region == code, 1, 0)
    data_columns.append(column_name)

# %%
X = sacramento[data_columns]
ols.fit(X,y)
zip(data_columns, ols.coef_)
# Out:
# [('beds', -1717.5465786287725),
#  ('baths', 31701.696586566875),
#  ('sq__ft', 42.633801749681879),
#  ('latitude', -199990.08540362481),
#  ('longitude', 264676.89210309519),
#  ('river_south', -76140.747761583276),
#  ('northeast', 16144.544955506761),
#  ('p9582', -58791.837847574876),
#  ('p9583', 21289.726021566719),
#  ('p9567', 23511.305794256958),
#  ('p9574', 168306.54821375155),
#  ('p9562', -40191.774370647283),
#  ('p9566', -12619.868947400217),
#  ('p9576', 187682.74789099692)]

# %%
ols.score(X,y)
# Out:
# 0.41503138558963693

# %%
sacramento['bed_bath_ratio'] = sacramento.beds / sacramento.baths
sacramento.dropna(inplace=True)
data_columns.append('bed_bath_ratio')

# %%
X = sacramento[data_columns]
y = sacramento.price
ols.fit(X,y)
print ols.score(X,y)
zip(data_columns, ols.coef_)
# Out:
# 0.481609455351
# [('beds', -7094.5161474702054),
#  ('baths', 83222.684543876196),
#  ('sq__ft', 44.181172740878537),
#  ('latitude', 8148.1194935584335),
#  ('longitude', 230520.6085823355),
#  ('river_south', -44701.336883283744),
#  ('northeast', -5086.9281846292579),
#  ('p9582', -54983.158444009554),
#  ('p9583', -23805.490892346239),
#  ('p9567', -10670.350373974492),
#  ('p9574', 92337.972530860541),
#  ('p9562', -51272.097358067622),
#  ('p9566', -25581.602533753496),
#  ('p9576', 136682.08595388438),
#  ('bed_bath_ratio', 10866.67549080099),
#  ('bed_bath_ratio', 10866.675490801033),
#  ('bed_bath_ratio', 10866.67549080115),
#  ('bed_bath_ratio', 10866.67549080115)]

# %%
ols.fit(X[sacramento.type == 'Residential'],
        y[sacramento.type == 'Residential'])
print ols.score(X[sacramento.type == 'Residential'],
                y[sacramento.type == 'Residential'])
# Out:
# 0.491745657517

# %%
ols.fit(X[sacramento.type == 'Condo'],
        y[sacramento.type == 'Condo'])
print ols.score(X[sacramento.type == 'Condo'],
                y[sacramento.type == 'Condo'])
# Out:
# 0.631379737899
