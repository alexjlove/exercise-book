# %% [markdown]
# # PCA Lab II

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
import seaborn as sns
import math
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from sklearn.cluster import KMeans
from sklearn import metrics

# %matplotlib inline

# %% [markdown]
# ## Step 1: Setup the Data

# %% [markdown]
# After you've downloaded the data from the repository, go ahead and load it with Pandas

# %%
airports = pd.read_csv('../CSV/Airport_operations.csv')

# %%
airports.head()
# Out:
#   airport  year  departures for metric computation  \
# 0     ABQ  2004                              53971
# 1     ABQ  2005                              51829
# 2     ABQ  2006                              49682
# 3     ABQ  2007                              53255
# 4     ABQ  2008                              49589
#
#    arrivals for metric computation  percent on-time gate departures  \
# 0                            53818                           0.8030
# 1                            51877                           0.8140
# 2                            51199                           0.7983
# 3                            53611                           0.8005
# 4                            49512                           0.8103
#
#    percent on-time airport departures  percent on-time gate arrivals  \
# 0                              0.7809                         0.7921
# 1                              0.7922                         0.8001
# 2                              0.7756                         0.7746
# 3                              0.7704                         0.7647
# 4                              0.7844                         0.7875
#
#    average_gate_departure_delay  average_taxi_out_time  \
# 0                         10.38                   9.89
# 1                          9.60                   9.79
# 2                         10.84                   9.89
# 3                         11.29                  10.34
# 4                         10.79                  10.41
#
#    average taxi out delay  average airport departure delay  \
# 0                    2.43                            12.10
# 1                    2.29                            11.20
# 2                    2.16                            12.33
# 3                    2.40                            12.95
# 4                    2.41                            12.32
#
#    average airborne delay  average taxi in delay  average block delay  \
# 0                    2.46                   0.83                 2.55
# 1                    2.26                   0.89                 2.34
# 2                    2.12                   0.84                 2.66
# 3                    2.19                   1.29                 3.06
# 4                    1.82                   1.03                 2.79
#
#    average gate arrival delay
# 0                       10.87
# 1                       10.24
# 2                       11.82
# 3                       12.71
# 4                       11.48

# %% [markdown]
# ## Step 2: Explore the Data

# %% [markdown]
# Next - Let's plot! You can use any plotting library of your choice, but be sure to explore all of the data.

# %%
sns.pairplot(airports.drop('year', axis=1))

# %% [markdown]
# ## Step 3: Define the Variables

# %% [markdown]
# Next, let's define the x and y variables: Airport is going to be our "x" variable

# %%
X = airports.ix[:,2:].values
y = airports.ix[:,0].values

# %% [markdown]
# ## Step 4: Covariance Matrix

# %% [markdown]
# Then, standardize the x variable for analysis

# %%
X_standard = StandardScaler().fit_transform(X)

# %% [markdown]
# Next, create the covariance matrix from the standardized x-values and decompose these values to find the eigenvalues and eigenvectors

# %%
cov_mat = np.cov(X_standard.T)
eigenValues, eigenVectors = np.linalg.eig(cov_mat)

# %% [markdown]
# # Step 5: Eigenpairs

# %% [markdown]
# Then, check your eigenvalues and eigenvectors:

# %%
print eigenValues
print eigenVectors
# Out:
# [  6.43554591e+00   4.30034272e+00   8.46168848e-01   5.11389160e-01
#    4.68106591e-01   1.67784858e-01   1.20373902e-01   8.75752619e-02
#    6.42089840e-02   1.02498362e-02   2.85997229e-03   1.66983552e-04
#    7.03167500e-04]
# [[  1.15534165e-01  -4.14065994e-01  -3.99975407e-01  -1.44386242e-01
#     1.88812357e-01  -2.89427568e-01   5.58777294e-02  -8.74632562e-02
#     3.56070223e-02   2.10712103e-02  -1.29886455e-02  -7.07882813e-01
#     1.63345229e-01  -5.96511097e-01   8.40211411e-02   1.67045712e-03
#    -1.10337882e-02]]

# %% [markdown]
# To find the principal componants, find the eigenpairs, and sort them from highest to lowest.

# %%
eig_pairs = [(np.abs(eigenValues[i]), eigenVectors[:,i]) for i in range(len(eigenValues))]
eig_pairs.sort()
eig_pairs.reverse()
for i in eig_pairs:
    print(i[0])
# Out:
# 6.43554590921
# 4.30034271686
# 0.84616884844
# 0.511389159623
# 0.468106590922
# 0.167784858101
# 0.120373901809
# 0.0875752619392
# 0.0642089840261
# 0.0102498362064
# 0.002859972289
# 0.000703167500326
# 0.000166983552113

# %% [markdown]
# ## Step 6: Explained Variance

# %% [markdown]
# Now, calculate the explained variance and the Cumulative explained variance

# %%
tot = sum(eigenValues)
var_exp = [(i / tot)*100 for i in sorted(eigenValues, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
print cum_var_exp
# Out:
# [  49.44533581   82.48556156   88.98681312   92.91589841   96.51243674
#    97.80155483   98.72640691   99.39926175   99.89258972   99.97134086
#    99.99331449   99.99871704  100.        ]

# %% [markdown]
# ** What does the explained variance tell us?**: Here, we can see that 81.77% of the behavior can be explained by the first two principal components

# %% [markdown]
# ## Step 7: Perform the PCA

# %% [markdown]
# Instead of creating the projection matrix, we're going to use Scikit's built in function. Now that we have discovered the principal componants, we have an educated idea on how many componants to pass to the function.

# %%
PCA_sk = PCA(n_components=2)
Y_sk = PCA_sk.fit_transform(X_standard)

# %% [markdown]
# Create a dataframe from the PCA results

# %%
new_X = pd.DataFrame(Y_sk, columns=['PC1', 'PC2'])

# %% [markdown]
# Now, create a new dataframe that uses the airport and year from the original set and join the PCA results with it to form a new set

# %%
new_df = airports[['airport', 'year']]
new_df = new_df.join(new_X)

# %%
new_df.head()
# Out:
#   airport  year       PC1       PC2
# 0     ABQ  2004 -2.104891  0.769690
# 1     ABQ  2005 -2.501786  0.700678
# 2     ABQ  2006 -1.947183  0.990674
# 3     ABQ  2007 -1.512762  0.725494
# 4     ABQ  2008 -2.061681  0.748124

# %% [markdown]
# Next, graph the results onto the new feature space

# %%
graph = new_df.plot(kind='scatter', x='PC2', y='PC1', figsize=(16,8))

for i, airport in enumerate(airports['airport']):
    graph.annotate(airport, (new_df.iloc[i].PC2, new_df.iloc[i].PC1))

# %% [markdown]
# **What does the graph tell us?**

# %% [markdown]
# ## Step 8: Cluster with K-Means

# %% [markdown]
# Set up the k-means clustering analysis. Use the graph from above to derive "k"

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(new_X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# Compute the labels and centroids

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %% [markdown]
# Compute the Silhoutte Score

# %%
metrics.silhouette_score(new_X, labels, metric='euclidean')
# Out:
# 0.52432332867947107

# %% [markdown]
# Lastly, plot the new two-dimensional data along with their cluster assignments:

# %%
new_df['cluster'] = pd.Series(labels)

# %%
graph2 =new_df.plot(
    kind='scatter',
    x='PC2',y='PC1',
    c=new_df.cluster.astype(np.float), 
    figsize=(16,8))

for i, airport in enumerate(airports['airport']):
    graph.annotate(airport, (new_df.iloc[i].PC2, new_df.iloc[i].PC1))
