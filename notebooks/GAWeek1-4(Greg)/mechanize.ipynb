# %%
# !pip install mechanize --upgrade
# Out:
# Requirement already up-to-date: mechanize in /home/useraj/anaconda2/lib/python2.7/site-packages

# %%
import mechanize

# %%
br = mechanize.Browser()
br.set_handle_robots(False)
page = br.open("http://www.indeed.com/")
source_code = page.read()
print source_code
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Job Search | one search. all jobs. Indeed.com</title>
# <meta name="description" content="Click here to find millions of jobs from thousands of company web sites, job boards and newspapers. one search. all jobs. Indeed.">
# <meta name="keywords" content="job search, Indeed, jobs, search engine for jobs, job search engine, job listings, search jobs, career, employment, work, find jobs, rss jobs feed xml ">
# <link rel="canonical" href="/">
# <link rel="alternate" media="handheld" href="/m/">
# <link href="https://plus.google.com/113999236499154807366" rel="publisher" />
# <link rel="alternate" href="android-app://com.indeed.android.jobsearch/http/www.indeed.com/m/">
# <meta http-equiv="content-type" content="text/html; charset=utf-8">
# <style type="text/css">
# ...

# %%
br.select_form(name='jobsearch')

br['what'] = 'Data Scientist'
br['where'] = 'San Francisco'

return b.submit()
# Out:
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# <ipython-input-12-1b6f3fa15f9b> in <module>()
# ----> 1 br.select_form(name='jobsearch')
#       2
#       3 br['what'] = 'Data Scientist'
#       4 br['where'] = 'San Francisco'
#       5
#
# /home/useraj/anaconda2/lib/python2.7/site-packages/mechanize/_mechanize.pyc in select_form(self, name, predicate, nr)
#     497                 "at least one argument must be supplied to specify form")
#     498
# --> 499         global_form = self._factory.global_form
#     500         if nr is None and name is None and \
#     501                predicate is not None and predicate(global_form):
#
# /home/useraj/anaconda2/lib/python2.7/site-packages/mechanize/_html.pyc in __getattr__(self, name)
#     542             return self.title
#     543         elif name == "global_form":
# --> 544             self.forms()
# ...
