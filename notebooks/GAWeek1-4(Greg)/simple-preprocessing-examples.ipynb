# %%
# %matplotlib inline

# %%
import pandas

# %%
sydtrains = pandas.read_csv('sydtrains.csv')
sydtrains
# Out:
#                              LINE                 STATION  YEAR  \
# 0                             CBD                 Central  2014
# 1                             CBD               Town Hall  2014
# 2                             CBD                 Wynyard  2014
# 3                         Western              Parramatta  2014
# 4                     North Shore            North Sydney  2014
# 5                             CBD                 Redfern  2014
# 6                     North Shore               Chatswood  2014
# 7                 Eastern Suburbs          Bondi Junction  2014
# 8                      Inner West             Strathfield  2014
# 9                             CBD           Circular Quay  2014
# 10                            CBD            Martin Place  2014
# 11                      Illawarra              Hurstville  2014
# 12                    North Shore             St Leonards  2014
# 13                        Western               Blacktown  2014
# ...

# %% [markdown]
# # Indexing
#
# A natural index is the station, not the row number in the file.

# %%
sydtrains = pandas.read_csv('sydtrains.csv', index_col=1)
sydtrains
# Out:
#                                                LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Central                                         CBD  2014        6/05/2014
# Town Hall                                       CBD  2014        7/05/2014
# Wynyard                                         CBD  2014       20/05/2014
# Parramatta                                  Western  2014       19/11/2014
# North Sydney                            North Shore  2014       19/08/2014
# Redfern                                         CBD  2014        1/05/2014
# Chatswood                               North Shore  2014       19/08/2014
# Bondi Junction                      Eastern Suburbs  2014        2/09/2014
# Strathfield                              Inner West  2014        9/09/2014
# Circular Quay                                   CBD  2014       22/05/2014
# Martin Place                                    CBD  2014       27/05/2014
# ...

# %%
sydtrains.OUT_0600_0930.head()
# Out:
# STATION
# Central         42070
# Town Hall       43210
# Wynyard         39620
# Parramatta      13700
# North Sydney    18340
# Name: OUT_0600_0930, dtype: int64

# %%
sydtrains.OUT_0600_0930.head().plot.barh()

# %% [markdown]
# # Date columns

# %%
def dateparse(x):
    try:
        return pandas.datetime.strptime(x, '%d/%m/%Y')
    except ValueError:
        pass
    try:
        return pandas.datetime.strptime(x, "%b-%y")
    except ValueError:
        pass
    if "-" in x:
        (lhs, rhs) = x.split('-',1)
        return dateparse(rhs)

sydtrains = pandas.read_csv('sydtrains.csv',
                            index_col=1,
                            parse_dates=['SURVEY_DATE_USED'],
                            date_parser=dateparse
                           )
sydtrains
# Out:
#                                                LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Central                                         CBD  2014       2014-05-06
# Town Hall                                       CBD  2014       2014-05-07
# Wynyard                                         CBD  2014       2014-05-20
# Parramatta                                  Western  2014       2014-11-19
# North Sydney                            North Shore  2014       2014-08-19
# Redfern                                         CBD  2014       2014-05-01
# Chatswood                               North Shore  2014       2014-08-19
# Bondi Junction                      Eastern Suburbs  2014       2014-09-02
# Strathfield                              Inner West  2014       2014-09-09
# Circular Quay                                   CBD  2014       2014-05-22
# Martin Place                                    CBD  2014       2014-05-27
# ...

# %% [markdown]
# Let's check some data types

# %%
sydtrains.SURVEY_DATE_USED
# Out:
# STATION
# Central                  2014-05-06
# Town Hall                2014-05-07
# Wynyard                  2014-05-20
# Parramatta               2014-11-19
# North Sydney             2014-08-19
# Redfern                  2014-05-01
# Chatswood                2014-08-19
# Bondi Junction           2014-09-02
# Strathfield              2014-09-09
# Circular Quay            2014-05-22
# Martin Place             2014-05-27
# Hurstville               2014-05-28
# St Leonards              2014-05-27
# Blacktown                2014-10-14
# Burwood                  2014-09-09
# Kings Cross              2013-09-03
# Hornsby                  2014-05-14
# Ashfield                 2013-09-04
# Kogarah                  2014-06-19
# Lidcombe                 2014-06-05
# Auburn                   2014-11-19
# Museum                   2014-05-22
# Epping                   2014-05-21
# Macquarie University     2014-05-21
# St James                 2014-05-27
# Rockdale                 2014-05-28
# ...

# %% [markdown]
# Dates came back as datetime, but OUT_24_HOURS is object. I would have expected int64

# %%
sydtrains.OUT_24_HOURS
# Out:
# STATION
# Central                   97,110
# Town Hall                 89,620
# Wynyard                   60,200
# Parramatta                34,960
# North Sydney              28,610
# Redfern                   25,680
# Chatswood                 22,200
# Bondi Junction            21,880
# Strathfield               20,710
# Circular Quay             20,630
# Martin Place              20,630
# Hurstville                18,290
# St Leonards               17,590
# Blacktown                 16,560
# Burwood                   14,990
# Kings Cross               12,870
# Hornsby                   12,250
# Ashfield                  11,200
# Kogarah                   11,100
# Lidcombe                  10,910
# Auburn                    10,890
# Museum                    10,860
# Epping                    10,570
# Macquarie University      10,090
# St James                   9,850
# Rockdale                   9,640
# Cabramatta                 8,730
# Bankstown                  8,630
# ...

# %%
sydtrains = pandas.read_csv('sydtrains.csv',
                            index_col=1,
                            parse_dates=['SURVEY_DATE_USED'],
                            date_parser=dateparse,
                            thousands=","
                           )
sydtrains
# Out:
#                                                LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Central                                         CBD  2014       2014-05-06
# Town Hall                                       CBD  2014       2014-05-07
# Wynyard                                         CBD  2014       2014-05-20
# Parramatta                                  Western  2014       2014-11-19
# North Sydney                            North Shore  2014       2014-08-19
# Redfern                                         CBD  2014       2014-05-01
# Chatswood                               North Shore  2014       2014-08-19
# Bondi Junction                      Eastern Suburbs  2014       2014-09-02
# Strathfield                              Inner West  2014       2014-09-09
# Circular Quay                                   CBD  2014       2014-05-22
# Martin Place                                    CBD  2014       2014-05-27
# ...

# %%
sydtrains.OUT_24_HOURS
# Out:
# STATION
# Central                   97110
# Town Hall                 89620
# Wynyard                   60200
# Parramatta                34960
# North Sydney              28610
# Redfern                   25680
# Chatswood                 22200
# Bondi Junction            21880
# Strathfield               20710
# Circular Quay             20630
# Martin Place              20630
# Hurstville                18290
# St Leonards               17590
# Blacktown                 16560
# Burwood                   14990
# Kings Cross               12870
# Hornsby                   12250
# Ashfield                  11200
# Kogarah                   11100
# Lidcombe                  10910
# Auburn                    10890
# Museum                    10860
# Epping                    10570
# Macquarie University      10090
# St James                   9850
# Rockdale                   9640
# Cabramatta                 8730
# Bankstown                  8630
# Liverpool                  8350
# ...

# %% [markdown]
# Confirmed, the column is now numbers, not a mixture of numbers and strings.

# %% [markdown]
# # Understanding the data better
#
# What are the unique values for a column?

# %%
sydtrains.YEAR.unique()
# Out:
# array([2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004])

# %%
sydtrains.YEAR.nunique()
# Out:
# 11

# %% [markdown]
# We've already put the station name as the index,  so it isn't a column.

# %%
sydtrains.index.nunique()
# Out:
# 310

# %% [markdown]
# # Restricting to one particular category
#
# Perhaps we are only interested in a particular year, e.g. the last year before the Opal card was introduced.

# %%
trains2014_selector = sydtrains.YEAR == 2014

# %%
trains2014 = sydtrains[trains2014_selector].copy()
trains2014
# Out:
#                                                  LINE  YEAR SURVEY_DATE_USED  \
# STATION
# Central                                           CBD  2014       2014-05-06
# Town Hall                                         CBD  2014       2014-05-07
# Wynyard                                           CBD  2014       2014-05-20
# Parramatta                                    Western  2014       2014-11-19
# North Sydney                              North Shore  2014       2014-08-19
# Redfern                                           CBD  2014       2014-05-01
# Chatswood                                 North Shore  2014       2014-08-19
# Bondi Junction                        Eastern Suburbs  2014       2014-09-02
# Strathfield                                Inner West  2014       2014-09-09
# Circular Quay                                     CBD  2014       2014-05-22
# Martin Place                                      CBD  2014       2014-05-27
# ...

# %% [markdown]
# We needed to say "cop()" above so that we can add extra columns.
#
# (Otherwise we would be trying to add columns to a view over the existing data. Instead, we want to edit a fresh dataframe).

# %%
trains2014['differences'] = trains2014.IN_24_HOURS - trains2014.OUT_24_HOURS

# %% [markdown]
# # Dirtier Data
#
# The data about who survived the Titanic is much less complete.

# %%
titanic = pandas.read_csv('titanic.csv', index_col='PassengerId')
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
import matplotlib.pyplot

# %%
matplotlib.pyplot.scatter(titanic.Age, titanic.Survived)

# %%
ageless_passengers = titanic.Age.isnull()
passengers_with_an_age = titanic.Age.notnull()
some_passengers = titanic[passengers_with_an_age]
some_passengers.Name.count()
# Out:
# 714

# %%
survivors = titanic.Survived == 1
titanic[survivors].Name.count()
# Out:
# 342

# %%
x = '12,345'
list(x)
# Out:
# ['1', '2', ',', '3', '4', '5']

# %%
import nltk
nltk.word_tokenize(x)
# Out:
# ['12,345']
