# %% [markdown]
# # Multi-table Datasets - ENRON Archive

# %% [markdown]
# ## 1. Data import
#
# Connect to the file 'assets/datasets/enron.db' using one of these methods:
#
# - sqlite3 python package
# - pandas.read_sql
# - SQLite Manager Firefox extension
#
# Take a look at the database and query the master table. How many Tables are there in the db?
#
# > Answer:
# There are 3 tables:
# - MessageBase
# - RecipientBase
# - EmployeeBase

# %%
import sqlite3
c = sqlite3.connect('enron.db')

# %% [markdown]
# Query the `sqlite_master` table to retrieve the schema of the `EmployeeBase` table.
#
# 1. What fields are there?
# 1. What's the type of each of them?

# %%
data = c.execute('SELECT * FROM sqlite_master;')
data.fetchall()
# Out:
# [(u'view',
#   u'Employee',
#   u'Employee',
#   0,
#   u"CREATE VIEW Employee AS\nSELECT\n    eid,\n    name,\n    longdepartment,\n    title,\n\n    gender,\n    CASE gender\n        WHEN 'Female' THEN 1\n        ELSE 0\n    END AS genF,\n\n    seniority,\n    CASE seniority\n        WHEN 'Junior' THEN 1\n        ELSE 0\n    END AS senJ,\n\n    department,\n    CASE department\n        WHEN 'Legal' THEN 1\n        ELSE 0\n    END AS depL,\n    CASE department\n        WHEN 'Trading' THEN 1\n        ELSE 0\n    END AS depT\nFROM\n    EmployeeBase"),
#  (u'view',
#   u'EmployeeWithVars',
#   u'EmployeeWithVars',
#   0,
#   u'CREATE VIEW EmployeeWithVars AS\nSELECT\n    eid,\n    1 AS intercept,\n    genF,\n    senJ,\n    depL,\n    depT,\n    genF * senJ AS genF_senJ,\n    genF * depL AS genF_depL,\n    genF * depT AS genF_depT,\n    senJ * depL AS senJ_depL,\n    senJ * depT AS senJ_depT,\n    genF * senJ * depL AS genF_senJ_depL,\n    genF * senJ * depT AS genF_senJ_depT\nFROM\n    Employee'),
#  (u'table',
#   u'MessageBase',
#   u'MessageBase',
#   3,
#   u'CREATE TABLE MessageBase (\n    mid INTEGER,\n    filename TEXT,\n    unix_time INTEGER,\n    subject TEXT,\n    from_eid INTEGER,\n    \n    PRIMARY KEY(mid ASC),\n    FOREIGN KEY(from_eid) REFERENCES Employee(eid)\n)'),
#  (u'index',
#   u'IX_MessageBase_unix_time',
#   u'MessageBase',
#   4,
#   u'CREATE INDEX IX_MessageBase_unix_time ON MessageBase(unix_time ASC)'),
#  (u'view',
#   u'Message',
#   u'Message',
#   0,
#   u"CREATE VIEW Message AS\nSELECT\n    mid,\n    filename,\n    datetime(unix_time, 'unixepoch') AS time,\n    unix_time,\n    subject,\n    from_eid\nFROM\n    MessageBase"),
#  (u'table',
#   u'RecipientBase',
#   u'RecipientBase',
#   5,
#   u'CREATE TABLE RecipientBase (\n    mid INTEGER,\n    rno INTEGER,\n    to_eid INTEGER,\n    \n    PRIMARY KEY(mid ASC, rno ASC)\n    FOREIGN KEY(mid) REFERENCES Message(mid)\n    FOREIGN KEY(to_eid) REFERENCES Employee(eid)\n)'),
#  (u'index', u'sqlite_autoindex_RecipientBase_1', u'RecipientBase', 6, None),
#  (u'view',
#   u'Recipient',
#   u'Recipient',
#   0,
#   u'CREATE VIEW Recipient AS\nSELECT\n    mid,\n    rno,\n    to_eid\nFROM\n    RecipientBase'),
#  (u'table',
#   u'EmployeeBase',
#   u'EmployeeBase',
#   2,
#   u'CREATE TABLE EmployeeBase (\n                  [eid] INTEGER,\n  [name] TEXT,\n  [department] TEXT,\n  [longdepartment] TEXT,\n  [title] TEXT,\n  [gender] TEXT,\n  [seniority] TEXT\n                  \n                  )')]

# %% [markdown]
# 1. Print the first 5 rows of EmployeeBase table
# 1. Print the first 5 rows of MessageBase table
# 1. Print the first 5 rows of RecipientBase table
#
# **Hint**  use `SELECT` and `LIMIT`.

# %%
import pandas as pd
pd.read_sql('SELECT * FROM EmployeeBase LIMIT 5;', con=conn)
# Out:
#    eid           name department     longdepartment             title  gender  \
# 0    1    John Arnold   Forestry  ENA Gas Financial        VP Trading    Male
# 1    2    Harry Arora   Forestry     ENA East Power        VP Trading    Male
# 2    3  Robert Badeer   Forestry     ENA West Power       Mgr Trading    Male
# 3    4   Susan Bailey      Legal          ENA Legal  Specialist Legal  Female
# 4    5      Eric Bass   Forestry      ENA Gas Texas            Trader    Male
#
#   seniority
# 0    Senior
# 1    Senior
# 2    Junior
# 3    Junior
# 4    Junior

# %%
import pandas as pd
pd.read_sql('SELECT * FROM MessageBase LIMIT 5;', con=conn)
# Out:
#    mid          filename  unix_time                    subject  from_eid
# 0    1  taylor-m/sent/11  910930020             Cd$ CME letter       138
# 1    2  taylor-m/sent/17  911459940            Indemnification       138
# 2    3  taylor-m/sent/18  911463840        Re: Indemnification       138
# 3    4  taylor-m/sent/23  911874180     Re: Coral Energy, L.P.       138
# 4    5  taylor-m/sent/27  912396120  Bankruptcy Code revisions       138

# %%
import pandas as pd
pd.read_sql('SELECT * FROM RecipientBase LIMIT 5;', con=conn)
# Out:
#    mid  rno  to_eid
# 0    1    1      59
# 1    2    1      15
# 2    3    1      15
# 3    4    1     109
# 4    4    2      49

# %% [markdown]
# Import each of the 3 tables to a Pandas Dataframes

# %%
employeedf = pd.DataFrame(pd.read_sql('SELECT * FROM EmployeeBase;', con=conn))
messagedf = pd.DataFrame(pd.read_sql('SELECT * FROM MessageBase;', con=conn))
recipientdf = pd.DataFrame(pd.read_sql('SELECT * FROM RecipientBase;', con=conn))

# %% [markdown]
# ## 2. Data Exploration
#
# Use the 3 dataframes to answer the following questions:
#
# 1. How many employees are there in the company?
# - How many messages are there in the database?
# - Convert the timestamp column in the messages. When was the oldest message sent? And the newest?
# - Some messages are sent to more than one recipient. Group the messages by message_id and count the number of recepients. Then look at the distribution of recepient numbers.
#     - How many messages have only one recepient?
#     - How many messages have >= 5 recepients?
#     - What's the highest number of recepients?
#     - Who sent the message with the highest number of recepients?
# - Plot the distribution of recepient numbers using Bokeh.

# %%
len(employeedf)
# Out:
# 156

# %%
len(messagedf)
# Out:
# 21635

# %%
messagedf['date'] = pd.to_datetime(messagedf["unix_time"], unit='s')
messagedf.dtypes
# Out:
# mid                   int64
# filename             object
# unix_time             int64
# subject              object
# from_eid              int64
# date         datetime64[ns]
# dtype: object

# %%
print min(messagedf.date)
print max(messagedf.date)
# Out:
# 1998-11-13 04:07:00
# 2002-06-21 13:37:34

# %%
rec_by_message = pd.pivot_table(recipientdf, 
                                index=['mid'], 
                                values=["to_eid"], 
                                aggfunc=len
                               )
print "Messages that have only one recipient: ", len(rec_by_message[rec_by_message.to_eid == 1])
print "Messages that have 5 or more recipients: ", len(rec_by_message[rec_by_message.to_eid >= 5])
print "Highest number of recipients: ", max(rec_by_message.to_eid)
# Out:
# Messages that have only one recipient:  14985
# Messages that have 5 or more recipients:  1380
# Highest number of recipients:  57

# %%
messageid = rec_by_message.loc[rec_by_message.to_eid == max(rec_by_message.to_eid)].index.values[0]

pd.read_sql('SELECT from_eid FROM MessageBase WHERE mid=' + str(messageid), con=conn)
pd.read_sql('SELECT name FROM EmployeeBase WHERE eid=67', con=conn)
# Out:
#                name
# 0  John J. Lavorato

# %%
messageid = rec_by_message.loc[rec_by_message.to_eid == max(rec_by_message.to_eid)].index.values[1]
pd.read_sql('SELECT from_eid FROM MessageBase WHERE mid=' + str(messageid), con=conn)
pd.read_sql('SELECT name FROM EmployeeBase WHERE eid=67', con=conn)
# Out:
#                name
# 0  John J. Lavorato

# %%
from bokeh.charts import Histogram, show, output_notebook

hist = Histogram(rec_by_message, values='to_eid', color='green',
                 title="Distribution of Recipient Numbers")

output_notebook()
show(hist)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c688da13-05ef-4b52-b1bb-455f26d4da58">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="b290764d-e906-41a6-85b5-cdd908a08f0a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b290764d-e906-41a6-85b5-cdd908a08f0a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b290764d-e906-41a6-85b5-cdd908a08f0a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b290764d-e906-41a6-85b5-cdd908a08f0a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7bf7ad25-cd7a-4475-85a2-f4a77742211d":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(45.4, 45.5]"],"color":["green"],"fill_alpha":[0.8],"height":[0.0],"label":["(45.4, 45.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0717029449423805],"x":["45.45"],"y":[0.0]}},"id":"eb07836b-d4cf-46cd-bb87-c324df7e7a51","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"9a17092b-f7f3-4470-bb1f-a4d2dc15a4c4","type":"ColumnDataSource"},"glyph":{"id":"931ea0a2-59d1-4102-a135-ef4d81bac449","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cc939239-3513-45d0-b73a-e50b89b0760b","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"89228a1f-3f35-4b5b-b001-587ff750ec02","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(54.6, 54.7]"],"color":["green"],"fill_alpha":[0.8],"height":[0.0],"label":["(54.6, 54.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0717029449423876],"x":["54.65"],"y":[0.0]}},"id":"c6a07544-6a73-43c9-9647-5dbb17cf865f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(27.7, 27.7]"],"color":["green"],"fill_alpha":[0.8],"height":[0.0],"label":["(27.7, 27.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0717029449423805],"x":["27.7"],"y":[0.0]}},"id":"6d6313f9-cc2d-42f6-afef-617dd3608472","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ee351e49-4efb-4efb-828a-164712e251f9","type":"Rect"},{"attributes":{"data_source":{"id":"81c7738c-5826-4e3b-ba98-cf9beafc8cbd","type":"ColumnDataSource"},"glyph":{"id":"9b5d8f9a-960b-4673-930c-476970ec346b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"63d90a13-49ba-4e79-8fe4-3da93fded3b7","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(47.5, 47.6]"],"color":["green"],"fill_alpha":[0.8],"height":[0.0],"label":["(47.5, 47.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0717029449423805],"x":["47.55"],"y":[0.0]}},"id":"a92b134f-423f-4c8b-b29e-2f6a054c28dd","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"06b41990-5dc9-4de2-bcae-e6fcf5dfcec8","type":"ColumnDataSource"},"glyph":{"id":"cf32dfa3-073a-4b1c-87e9-87a45de78be5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fa963124-9f2e-423a-bb37-f6c443ed4513","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(17.3, 17.3]"],"color":["green"],"fill_alpha":[0.8],"height":[0.0],"label":["(17.3, 17.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.07170294494238405],"x":["17.3"],"y":[0.0]}},"id":"3156d931-4855-4e19-8b44-17591a6f1ddd","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(5.8, 5.9]"],"color":["green"],"fill_alpha":[0.8],"height":[0.0],"label":["(5.8, 5.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.07170294494238139],"x":["5.85"],"y":[0.0]} ...

# %% [markdown]
# Rescale to investigate the tail of the curve

# %% [markdown]
# ## 3. Data Merging
#
# Use the pandas merge function to combine the information in the 3 dataframes to answer the following questions:
#
# 1. Are there more Men or Women employees?

# %%
pd.pivot_table(employeedf, index=["gender"], values=["name"], aggfunc=len)
# Out:
#         name
# gender
# Female    43
# Male     113

# %% [markdown]
# - How is gender distributed across departments?

# %%
pd.pivot_table(employeedf, index=['department', "gender"], values=["name"], aggfunc=len)
# Out:
#                    name
# department gender
# Forestry   Female    10
#            Male      50
# Legal      Female    13
#            Male      12
# Other      Female    20
#            Male      51

# %% [markdown]
# - Who is sending more emails? Men or Women?

# %%
df = pd.merge(employeedf, messagedf, left_on='eid', right_on='from_eid')
df.gender.value_counts()
# Out:
# Male      12841
# Female     8794
# Name: gender, dtype: int64

# %% [markdown]
# - What's the average number of emails sent by each gender?

# %%
df.gender.value_counts() / employeedf.gender.value_counts()
# Out:
# Male      113.637168
# Female    204.511628
# Name: gender, dtype: float64

# %% [markdown]
# - Are there more Juniors or Seniors?

# %%
employeedf.pivot_table(index=['seniority'], values=['eid'], aggfunc=len)
# Out:
#            eid
# seniority
# Junior      82
# Senior      74

# %% [markdown]
# - Who is sending more emails? Juniors or Seniors?

# %%
df.seniority.value_counts()
# Out:
# Senior    12439
# Junior     9196
# Name: seniority, dtype: int64

# %% [markdown]
# - Which department is sending more emails? How does that relate with the number of employees in the department?

# %%
df.department.value_counts()
# Out:
# Legal       10396
# Other        6852
# Forestry     4387
# Name: department, dtype: int64

# %% [markdown]
# - Who are the top 3 senders of emails? (people who sent out the most emails)

# %%
# Who are the top 5 senders of emails? (people who sent out the most emails)
top5senders = df.eid.value_counts().head().reset_index()
top5senders.columns = ['eid', 'msgs_sent']
pd.merge(employeedf, top5senders, on='eid')
# Out:
#    eid              name department                     longdepartment  \
# 0   20     Jeff Dasovich      Legal  Regulatory and Government Affairs
# 1   59        Tana Jones      Legal                          ENA Legal
# 2  120   Sara Shackleton      Legal                          ENA Legal
# 3  131  James D. Steffes      Legal  Regulatory and Government Affairs
# 4  138    Mark E. Taylor      Legal                          ENA Legal
#
#                       title  gender seniority  msgs_sent
# 0                  Director    Male    Senior       1597
# 1          Specialist Legal  Female    Junior       1379
# 2             Gen Cnsl Asst  Female    Junior       1142
# 3  VP of Government Affairs    Male    Senior        859
# 4             VP & Gen Cnsl    Male    Senior        658

# %% [markdown]
# **Answer the following questions regarding received messages:**
#
# - Who is receiving more emails? Men or Women?

# %%
new_df2 = recipientdf.pivot_table(index=['to_eid'], values=['mid'], aggfunc= len)
piv2 = new_df2.merge(employeedf, how='left', left_index=True, right_index=True)
piv2.pivot_table(index=['gender'], values=['mid'], aggfunc=sum)
# Out:
#           mid
# gender
# Female   8496
# Male    29554

# %% [markdown]
# - Who is receiving more emails? Juniors or Seniors?

# %%
piv2.pivot_table(index=['seniority'], values=['mid'], aggfunc=sum)
# Out:
#              mid
# seniority
# Junior     19843
# Senior     18207

# %% [markdown]
# - Which department is receiving more emails? How does that relate with the number of employees in the department?

# %%
piv2.pivot_table(index=['department'], values=['mid'], aggfunc=sum)
# Out:
#               mid
# department
# Forestry    16327
# Legal        5372
# Other       16351

# %% [markdown]
# - Who are the top 5 receivers of emails? (people who received the most emails)

# %% [markdown]
# Which employees sent the most 'mass' emails?

# %% [markdown]
# Keep exploring the dataset, which other questions would you ask?
#
# Work in pairs. Give each other a challenge and try to solve it.
